# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Using all features,Playoffs training on that seasons regular season split 75% to last 25%

# %%
Accuracy_scores_log=[56.7,59.6,58.5,64.4,57.3,52.8]
Accuracy_scores_knn=[61.8,63.5,65.1,65.5,57.3,53.9]
Accuracy_scores_rf=[70.3,70.3,69.5,72.3,64.0,56.2]
year_yof=[0,2016,2017,2018,2019,2020,2021]

# %% [markdown]
# Drop zero importance features and 75%, 25% split

# %%
acc_log_zero_dict={65.3:96,70.7:111,67.1:145,70.9:163,71.4:10,50.0:9}
acc_knn_zero_dict={68.0:121,67.6:198,72.1:160,76.4:145,69.6:16,61.0:25}
acc_rf_zero_dict ={75.8:270,76.9:269,76.2:250,76.3:271,100.0:17,93.5:29}

# %% [markdown]
# Results when training on first 75% of season and testing on last 25%
# Using all features, adjusted accuracy score dropping games between 40-60% confidence.

# %%
Acc_75_25_log_dict={65.2:105,68.2:101,68.8:130,72.1:189,71.4:10,50.0:9}
Acc_75_25_knn_dict={70.2:132,69.6:133,68.9:229,77.0:157,69.6:16,61.0:25}
Acc_75_25_rf_dict ={75.5:274,76.6:268,76.1:252,76.4:269,100.0:18,100:28}

# %%
Acc_75_25_log=[65.2,68.2,68.8,72.1,71.4,50.0]
Acc_75_25_knn=[70.2,69.6,68.9,77.0,69.6,61.0]
Acc_75_25_rf =[75.5,76.6,76.1,76.4,100.0,100.0]
fig, ax= plt.subplots()
ax.plot(Acc_75_25_log,label='Logistic Regression')
ax.plot(Acc_75_25_knn,label='knn')
ax.plot(Acc_75_25_rf,label='Random Forest')
ax.legend();

# %% [markdown]
# Adjusted Accuracy Scores on 75/25 season split

# %%
data = [Acc_75_25_log,
Acc_75_25_knn,
Acc_75_25_rf]
X = np.arange(6)
fig = plt.figure(figsize=(15,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.25, data[0], color = 'b', width = 0.25,label='Logistic Regression',edgecolor='black')
ax.bar(X + 0.00, data[1], color = 'g', width = 0.25,label='KNN',edgecolor='black')
ax.bar(X + 0.25, data[2], color = 'r', width = 0.25,label='Random Forest',edgecolor='black')
ax.set_title('Adjusted Accuracy Scores')
ax.legend()
ax.set_xticklabels(year_yof)
ax.set_ylabel('Accuracy in %')
ax.set_xlabel('Years');
# Out:
# <ipython-input-6-e67c42883723>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(year_yof)

# %% [markdown]
# Games bet on by each model, year to year

# %%
games_75_25_log=[105,101,130,189,10,9]
games_75_25_knn=[132,133,229,157,16,25]
games_75_25_rf =[274,268,252,269,18,28]

# %%
data = [games_75_25_log,
games_75_25_knn,
games_75_25_rf]
X = np.arange(6)
fig = plt.figure(figsize=(15,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.25, data[0], color = 'b', width = 0.25,label='Logistic Regression',edgecolor='black')
ax.bar(X + 0.00, data[1], color = 'g', width = 0.25,label='KNN',edgecolor='black')
ax.bar(X + 0.25, data[2], color = 'r', width = 0.25,label='Random Forest',edgecolor='black')
ax.set_title('Games Bet on by Year')
ax.legend()
ax.set_xticklabels(year_yof)
ax.set_ylabel('Amount of Games Bet')
ax.set_xlabel('Years')
;
# Out:
# <ipython-input-8-4da523b1510e>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(year_yof)
# ''

# %%
data = [Accuracy_scores_log,
Accuracy_scores_knn,
Accuracy_scores_rf]
X = np.arange(6)
fig = plt.figure(figsize=(15,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.25, data[0], color = 'b', width = 0.25,label='Logistic Regression',edgecolor='black')
ax.bar(X + 0.00, data[1], color = 'g', width = 0.25,label='KNN',edgecolor='black')
ax.bar(X + 0.25, data[2], color = 'r', width = 0.25,label='Random Forest',edgecolor='black')
ax.set_title('Accuracy Scores')
ax.legend()
ax.set_xticklabels(year_yof)
ax.set_ylabel('Accuracy in %')
ax.set_xlabel('Years')
ax.set_ylim(top=100);
# Out:
# <ipython-input-9-14c99ba660f6>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(year_yof)

# %% [markdown]
# Dropped zero importance 75/25:

# %%
acc_log_zero=[65.3,70.7,67.1,70.9,71.4,50.0]
acc_knn_zero=[68.0,67.6,72.1,76.4,69.6,61.0]
acc_rf_zero=[75.8,76.9,76.2,76.3,100.0,93.5]

# %%
games_log_zero=[96,111,145,163,10,9]
games_knn_zero=[121,198,160,145,16,25]
games_rf_zero =[270,269,250,271,17,29]

# %%
data = [games_log_zero,
games_knn_zero,
games_rf_zero]
X = np.arange(6)
fig = plt.figure(figsize=(15,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.25, data[0], color = 'b', width = 0.25,label='Logistic Regression',edgecolor='black')
ax.bar(X + 0.00, data[1], color = 'g', width = 0.25,label='KNN',edgecolor='black')
ax.bar(X + 0.25, data[2], color = 'r', width = 0.25,label='Random Forest',edgecolor='black')
ax.set_title('Games Bet on by Year Dropped Zero Importance')
ax.legend()
ax.set_xticklabels(year_yof)
ax.set_ylabel('Amount of Games Bet')
ax.set_xlabel('Years');
# Out:
# <ipython-input-12-5eae0ce57dab>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(year_yof)

# %%
data = [acc_log_zero,
acc_knn_zero,
acc_rf_zero]
X = np.arange(6)
fig = plt.figure(figsize=(15,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.25, data[0], color = 'b', width = 0.25,label='Logistic Regression',edgecolor='black')
ax.bar(X + 0.00, data[1], color = 'g', width = 0.25,label='KNN',edgecolor='black')
ax.bar(X + 0.25, data[2], color = 'r', width = 0.25,label='Random Forest',edgecolor='black')
ax.set_title('Adjusted Accuracy Scores Dropped Zero Importance')
ax.legend()
ax.set_xticklabels(year_yof)
ax.set_ylabel('Accuracy in %')
ax.set_xlabel('Years');
# Out:
# <ipython-input-13-e45f6f941d5c>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(year_yof)

# %% [markdown]
# ### Compare Random Forests

# %%
data = [Acc_75_25_rf,
        acc_rf_zero]
X = np.arange(6)
fig = plt.figure(figsize=(15,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.150, data[0], color = 'b', width = 0.25,label='Random Forest All Features',edgecolor='black')
ax.bar(X + 0.15, data[1], color = 'r', width = 0.25,label='Random Forest Dropped',edgecolor='black')
ax.set_title('Adjusted Accuracy Scores Random Forest Comparison')
ax.legend()
ax.set_xticklabels(year_yof)
ax.set_ylabel('Accuracy in %')
ax.set_xlabel('Years');
# Out:
# <ipython-input-14-f346b64f7df5>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(year_yof)

# %%
data = [games_75_25_rf,
games_rf_zero]
X = np.arange(6)
fig = plt.figure(figsize=(15,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.15, data[0], color = 'b', width = 0.25,label='Random Forest All Features',edgecolor='black')
ax.bar(X + 0.15, data[1], color = 'r', width = 0.25,label='Random Forest Dropped ',edgecolor='black')
ax.set_title('Games Bet on by Year Dropped Zero Importance')
ax.legend()
ax.set_xticklabels(year_yof)
ax.set_ylabel('Amount of Games Bet')
ax.set_xlabel('Years');
# Out:
# <ipython-input-15-1be872d5cc53>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(year_yof)

# %% [markdown]
# # Random Forest Accuracy Scores Using PCA

# %%
rf_pca_dict={75.8:269,76.7:267,76.1:252,76.7:270,100.0:17,96.7:29}
rf_pca_zero_dict={75.5:274,76.6:268,75.8:254,76.3:271,100.0:17,100.0:28}
rf_pca_acc=[75.8,76.7,76.1,76.7,100.0,96.7]
rf_pca_games=[269,267,252,270,17,29]
rf_pca_zero_acc=[75.5,76.6,75.8,76.3,100.0,100.0]
rf_pca_zero_games=[274,268,254,271,17,28]

# %% [markdown]
# ### Mean Accuracy and Standard Deviations of all Random Forests

# %%
print(f'Mean Accuracy Random Forest PCA All Feats: {np.mean(rf_pca_acc)}%')
print(f'Mean Accuracy Random Forest PCA dropped zero: {np.mean(rf_pca_zero_acc)}%')
print(f'Mean Accuracy Random Forest RFECV All Feats: {np.mean(Acc_75_25_rf)}%')
print(f'Mean Accuracy Random Forest RFECV dropped zero: {np.mean(acc_rf_zero)}%')
# Out:
# Mean Accuracy Random Forest PCA All Feats: 83.66666666666667%
# Mean Accuracy Random Forest PCA dropped zero: 84.03333333333333%
# Mean Accuracy Random Forest RFECV All Feats: 84.10000000000001%
# Mean Accuracy Random Forest RFECV dropped zero: 83.11666666666666%

# %%
print(f'Standard Deviation Random Forest PCA All Feats: {np.std(rf_pca_acc)}')
print(f'Standard Deviation Random Forest PCA dropped zero: {np.std(rf_pca_zero_acc)}')
print(f'Standard Deviation Random Forest RFECV All Feats: {np.std(Acc_75_25_rf)}')
print(f'Standard Deviation Random Forest RFECV dropped zero: {np.std(acc_rf_zero)}')
# Out:
# Standard Deviation Random Forest PCA All Feats: 10.431149931282214
# Standard Deviation Random Forest PCA dropped zero: 11.295525171008602
# Standard Deviation Random Forest RFECV All Feats: 11.248110952511094
# Standard Deviation Random Forest RFECV dropped zero: 9.826395857869533

# %% [markdown]
# ### Look at first 4 to get rid of Corona effected years

# %%
print(f'Mean Accuracy Random Forest PCA All Feats: {np.mean(rf_pca_acc[:4])}%')
print(f'Mean Accuracy Random Forest PCA dropped zero: {np.mean(rf_pca_zero_acc[:4])}%')
print(f'Mean Accuracy Random Forest RFECV All Feats: {np.mean(Acc_75_25_rf[:4])}%')
print(f'Mean Accuracy Random Forest RFECV dropped zero: {np.mean(acc_rf_zero[:4])}%')
# Out:
# Mean Accuracy Random Forest PCA All Feats: 76.325%
# Mean Accuracy Random Forest PCA dropped zero: 76.05%
# Mean Accuracy Random Forest RFECV All Feats: 76.15%
# Mean Accuracy Random Forest RFECV dropped zero: 76.3%

# %%
print(f'Standard Deviation Random Forest PCA All Feats: {np.std(rf_pca_acc[:4])}')
print(f'Standard Deviation Random Forest PCA dropped zero: {np.std(rf_pca_zero_acc[:4])}')
print(f'Standard Deviation Random Forest RFECV All Feats: {np.std(Acc_75_25_rf[:4])}')
print(f'Standard Deviation Random Forest RFECV dropped zero: {np.std(acc_rf_zero[:4])}')
# Out:
# Standard Deviation Random Forest PCA All Feats: 0.38971143170300054
# Standard Deviation Random Forest PCA dropped zero: 0.4272001872658747
# Standard Deviation Random Forest RFECV All Feats: 0.4153311931459032
# Standard Deviation Random Forest RFECV dropped zero: 0.39370039370059345

# %% [markdown]
# ### Mean Games used

# %%
print(np.mean(rf_pca_games[:4]))
print(np.mean(games_75_25_rf[:4]))
# Out:
# 264.5
# 265.75

# %% [markdown]
# ### Graph More Random Forest Comparisons

# %%
labels = ['PCA All Features', 'PCA Dropped', 'RFECV All Features', 'RFECV Dropped']
data =[np.mean(rf_pca_acc),np.mean(rf_pca_zero_acc),np.mean(Acc_75_25_rf),np.mean(acc_rf_zero)]


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax.bar(x - width/2, data[0], width,color='b', label=labels)
ax.bar(x - width/2, data[1], width,color='r', label=labels)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean Accuracy Score')
ax.set_title('Average Accuracy Random Forests')
ax.set_xticks(x, labels)
ax.legend()

#ax.bar_label(rects1, padding=3)

fig.tight_layout()

plt.show()
# Out:
# <ipython-input-22-f045589679d6>:14: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks(x, labels)

# %%
data = [rf_pca_acc,
Acc_75_25_rf]
X = np.arange(6)
fig = plt.figure(figsize=(15,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.15, data[0], color = 'b', width = 0.25,label='Random Forest: PCA',edgecolor='black')
ax.bar(X + 0.15, data[1], color = 'r', width = 0.25,label='Random Forest: RFECV ',edgecolor='black')
ax.set_title('Random Forest: RFECV vs. PCA')
ax.legend()
ax.set_xticklabels(year_yof)
ax.set_ylabel('Accuracy in %')
ax.set_xlabel('Years')
ax.set_facecolor('#EEC591')
fig.savefig('PCAvRFECV.png',dpi=300);
# Out:
# <ipython-input-42-55641ffe792d>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(year_yof)
