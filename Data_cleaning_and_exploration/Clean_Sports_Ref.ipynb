# %%
import pandas as pd

# %%
pitch=pd.read_csv('adv_pitch_2016.csv')

# %%
bat=pd.read_csv('adv_bat_2016.csv')

# %%
field=pd.read_csv('st_field_2016.csv')

# %%
pitch.columns=pitch.iloc[0]

# %%
pitch
# Out:
# 0                      Tm    BA   OBP   SLG   OPS  BAbip   HR%    SO%    BB%  \
# 0                      Tm    BA   OBP   SLG   OPS  BAbip   HR%    SO%    BB%
# 1    Arizona Diamondbacks  .275  .348  .454  .801   .323  3.1%  20.5%   9.4%
# 2          Atlanta Braves  .256  .328  .416  .744   .296  2.8%  19.6%   8.8%
# 3       Baltimore Orioles  .258  .328  .421  .750   .301  3.0%  20.4%   8.9%
# 4          Boston Red Sox  .246  .314  .397  .711   .295  2.9%  22.4%   8.1%
# 5            Chicago Cubs  .212  .285  .348  .633   .257  2.8%  24.3%   8.3%
# 6       Chicago White Sox  .257  .326  .419  .746   .300  3.0%  20.5%   8.4%
# 7         Cincinnati Reds  .263  .345  .456  .801   .294  4.1%  19.6%  10.0%
# 8       Cleveland Indians  .243  .304  .407  .711   .291  3.1%  23.2%   7.6%
# 9        Colorado Rockies  .274  .345  .446  .790   .321  2.9%  19.5%   8.7%
# 10         Detroit Tigers  .260  .320  .421  .741   .302  3.0%  20.4%   7.6%
# ...

# %%
pitch.head()
# Out:
# 0                    Tm    BA   OBP   SLG   OPS BAbip   HR%    SO%   BB%  \
# 1  Arizona Diamondbacks  .275  .348  .454  .801  .323  3.1%  20.5%  9.4%
# 2        Atlanta Braves  .256  .328  .416  .744  .296  2.8%  19.6%  8.8%
# 3     Baltimore Orioles  .258  .328  .421  .750  .301  3.0%  20.4%  8.9%
# 4        Boston Red Sox  .246  .314  .397  .711  .295  2.9%  22.4%  8.1%
# 5          Chicago Cubs  .212  .285  .348  .633  .257  2.8%  24.3%  8.3%
#
# 0    EV HardH%    LD%    GB%    FB% GB/FB    WPA   cWPA    RE24
# 1  89.6  42.5%  28.0%  45.7%  18.6%  0.87  -11.8  -2.0%  -142.3
# 2  89.6  41.8%  25.4%  44.3%  21.7%  0.83   -2.9  -1.2%   -71.5
# 3  89.1  40.0%  25.3%  45.2%  20.8%  0.84    6.5   6.7%    17.3
# 4  88.5  37.8%  23.0%  41.4%  25.8%  0.73    3.4   2.9%    54.7
# 5  88.8  38.7%  25.5%  46.6%  19.8%  0.91   18.2   7.4%   169.6

# %%
pitch.drop(index=[0,31,32],inplace=True)

# %%
bat.columns=bat.iloc[0]

# %%
bat.drop(index=[0,31,32],inplace=True)

# %%
bat.shape
# Out:
# (30, 23)

# %%
pitch.shape
# Out:
# (30, 18)

# %%
field.drop(['#Fld','G','GS','CG','Inn'],axis=1,inplace=True)

# %%
field.drop(index=[30,31],inplace=True)

# %%
field.head()
# Out:
#                      Tm  RA/G  DefEff    Ch    PO     A    E   DP   Fld%  \
# 0  Arizona Diamondbacks  5.49   0.665  6118  4354  1663  101  143  0.983
# 1        Atlanta Braves  4.84   0.692  6009  4343  1565  101  134  0.983
# 2     Baltimore Orioles  4.41   0.688  5955  4296  1579   80  165  0.987
# 3        Boston Red Sox  4.28   0.695  5821  4319  1427   75  139  0.987
# 4          Chicago Cubs  3.43   0.728  6115  4379  1635  101  116  0.983
#
#    Rtot  Rtot/yr  Rdrs  Rdrs/yr  Rgood
# 0   -31       -3   -24        2     11
# 1    10        1   -14       -1     -8
# 2   -11       -1     1        3      5
# 3    21        2    69        0     -1
# 4    96        9   107        1     -2

# %%
df=pd.read_csv('data/Season_2016_fav_win.csv')

# %%
sort_me=list(df.H_name.unique())

# %%
field.head()
# Out:
#                      Tm  RA/G  DefEff    Ch    PO     A    E   DP   Fld%  \
# 0  Arizona Diamondbacks  5.49   0.665  6118  4354  1663  101  143  0.983
# 1        Atlanta Braves  4.84   0.692  6009  4343  1565  101  134  0.983
# 2     Baltimore Orioles  4.41   0.688  5955  4296  1579   80  165  0.987
# 3        Boston Red Sox  4.28   0.695  5821  4319  1427   75  139  0.987
# 4          Chicago Cubs  3.43   0.728  6115  4379  1635  101  116  0.983
#
#    Rtot  Rtot/yr  Rdrs  Rdrs/yr  Rgood
# 0   -31       -3   -24        2     11
# 1    10        1   -14       -1     -8
# 2   -11       -1     1        3      5
# 3    21        2    69        0     -1
# 4    96        9   107        1     -2

# %%
field=field.replace({'Arizona Diamondbacks':'ARI','Atlanta Braves':'ATL','Baltimore Orioles':'BAL',
 'Boston Red Sox':'BOS','Chicago Cubs':'CHC','Chicago White Sox':'CHW','Cincinnati Reds':'CIN',
 'Cleveland Indians':'CLE','Colorado Rockies':'COL','Detroit Tigers':'DET','Houston Astros':'HOU',
 'Kansas City Royals':'KCR','Los Angeles Angels':'LAA','Los Angeles Dodgers':'LAD','Miami Marlins':'MIA',
 'Milwaukee Brewers':'MIL','Minnesota Twins':'MIN','New York Mets':'NYM','New York Yankees':'NYY',
 'Oakland Athletics':'OAK','Philadelphia Phillies':'PHI','Pittsburgh Pirates':'PIT','San Diego Padres':'SDP',
 'Seattle Mariners':'SEA','San Francisco Giants': 'SFG','St. Louis Cardinals':'STL','Tampa Bay Rays':'TBR',
 'Texas Rangers':'TEX','Toronto Blue Jays':'TOR','Washington Nationals':'WSN'})

# %%
field
# Out:
#      Tm  RA/G  DefEff    Ch    PO     A    E   DP   Fld%  Rtot  Rtot/yr  Rdrs  \
# 0   ARI  5.49   0.665  6118  4354  1663  101  143  0.983   -31       -3   -24
# 1   ATL  4.84   0.692  6009  4343  1565  101  134  0.983    10        1   -14
# 2   BAL  4.41   0.688  5955  4296  1579   80  165  0.987   -11       -1     1
# 3   BOS  4.28   0.695  5821  4319  1427   75  139  0.987    21        2    69
# 4   CHC  3.43   0.728  6115  4379  1635  101  116  0.983    96        9   107
# 5   CHW  4.41   0.687  5971  4340  1536   95  148  0.984     2        0    -2
# 6   CIN  5.27   0.694  5977  4326  1549  102  142  0.983     9        1   -14
# 7   CLE  4.20   0.696  6032  4335  1608   89  126  0.985    69        6    41
# 8   COL  5.31   0.667  6147  4288  1749  110  148  0.982     2        0    11
# 9   DET  4.48   0.689  5896  4284  1537   75  148  0.987   -40       -4   -57
# 10  HOU  4.33   0.681  6080  4404  1599   77  135  0.987   -14       -1    77
# ...

# %%
pitch=pitch.rename(columns={'BA':'BA_against','OBP':'OBP_against','SLG':"SLG_against",
                            'OPS':'OPS_against','BAbip':'BAbip_against','HR%':'HR%_against'})

# %%
pitch.drop('cWPA',axis=1,inplace=True)

# %%
pitch=pitch.replace({'Arizona Diamondbacks':'ARI','Atlanta Braves':'ATL','Baltimore Orioles':'BAL',
 'Boston Red Sox':'BOS','Chicago Cubs':'CHC','Chicago White Sox':'CHW','Cincinnati Reds':'CIN',
 'Cleveland Indians':'CLE','Colorado Rockies':'COL','Detroit Tigers':'DET','Houston Astros':'HOU',
 'Kansas City Royals':'KCR','Los Angeles Angels':'LAA','Los Angeles Dodgers':'LAD','Miami Marlins':'MIA',
 'Milwaukee Brewers':'MIL','Minnesota Twins':'MIN','New York Mets':'NYM','New York Yankees':'NYY',
 'Oakland Athletics':'OAK','Philadelphia Phillies':'PHI','Pittsburgh Pirates':'PIT','San Diego Padres':'SDP',
 'Seattle Mariners':'SEA','San Francisco Giants': 'SFG','St. Louis Cardinals':'STL','Tampa Bay Rays':'TBR',
 'Texas Rangers':'TEX','Toronto Blue Jays':'TOR','Washington Nationals':'WSN'})

# %%
pitch.head()
# Out:
# 0   Tm BA_against OBP_against SLG_against OPS_against BAbip_against  \
# 1  ARI       .275        .348        .454        .801          .323
# 2  ATL       .256        .328        .416        .744          .296
# 3  BAL       .258        .328        .421        .750          .301
# 4  BOS       .246        .314        .397        .711          .295
# 5  CHC       .212        .285        .348        .633          .257
#
# 0 HR%_against    SO%   BB%    EV HardH%    LD%    GB%    FB% GB/FB    WPA  \
# 1        3.1%  20.5%  9.4%  89.6  42.5%  28.0%  45.7%  18.6%  0.87  -11.8
# 2        2.8%  19.6%  8.8%  89.6  41.8%  25.4%  44.3%  21.7%  0.83   -2.9
# 3        3.0%  20.4%  8.9%  89.1  40.0%  25.3%  45.2%  20.8%  0.84    6.5
# 4        2.9%  22.4%  8.1%  88.5  37.8%  23.0%  41.4%  25.8%  0.73    3.4
# 5        2.8%  24.3%  8.3%  88.8  38.7%  25.5%  46.6%  19.8%  0.91   18.2
#
# 0    RE24
# 1  -142.3
# 2   -71.5
# 3    17.3
# 4    54.7
# 5   169.6

# %%
bat.drop(['cWPA'],axis=1,inplace=True)

# %%
bat=bat.replace({'Arizona Diamondbacks':'ARI','Atlanta Braves':'ATL','Baltimore Orioles':'BAL',
 'Boston Red Sox':'BOS','Chicago Cubs':'CHC','Chicago White Sox':'CHW','Cincinnati Reds':'CIN',
 'Cleveland Indians':'CLE','Colorado Rockies':'COL','Detroit Tigers':'DET','Houston Astros':'HOU',
 'Kansas City Royals':'KCR','Los Angeles Angels':'LAA','Los Angeles Dodgers':'LAD','Miami Marlins':'MIA',
 'Milwaukee Brewers':'MIL','Minnesota Twins':'MIN','New York Mets':'NYM','New York Yankees':'NYY',
 'Oakland Athletics':'OAK','Philadelphia Phillies':'PHI','Pittsburgh Pirates':'PIT','San Diego Padres':'SDP',
 'Seattle Mariners':'SEA','San Francisco Giants': 'SFG','St. Louis Cardinals':'STL','Tampa Bay Rays':'TBR',
 'Texas Rangers':'TEX','Toronto Blue Jays':'TOR','Washington Nationals':'WSN'})

# %%
#bat.to_csv('bat_2016.csv')
#pitch.to_csv('pitch_2016.csv')
#field.to_csv('field_2016.csv')

# %%
sports_ref=pd.read_csv('2016_ sports_ref_combined.csv')

# %%
sports_ref.drop('Unnamed: 0',axis=1,inplace=True)

# %%
sports_ref
# Out:
#      Tm  BA_against  OBP_against  SLG_against  OPS_against  BAbip_against  \
# 0   ARI       0.275        0.348        0.454        0.801          0.323
# 1   ATL       0.256        0.328        0.416        0.744          0.296
# 2   BAL       0.258        0.328        0.421        0.750          0.301
# 3   BOS       0.246        0.314        0.397        0.711          0.295
# 4   CHC       0.212        0.285        0.348        0.633          0.257
# 5   CHW       0.257        0.326        0.419        0.746          0.300
# 6   CIN       0.263        0.345        0.456        0.801          0.294
# 7   CLE       0.243        0.304        0.407        0.711          0.291
# 8   COL       0.274        0.345        0.446        0.790          0.321
# 9   DET       0.260        0.320        0.421        0.741          0.302
# 10  HOU       0.256        0.314        0.424        0.737          0.308
# 11  KCR       0.259        0.327        0.423        0.750          0.301
# ...
