# %% [markdown]
# # Data Exploration

# %%
#import relevant Packages
import pandas as pd
import numpy as np
from sportsipy.mlb.boxscore import Boxscore
from sportsipy.mlb.boxscore import Boxscores

# %%
from datetime import datetime
from sportsipy.mlb.boxscore import Boxscores

# %%
# Function to return games in certain time range
def get_current_games(date,end_date,end_week=None):
    
    games = Boxscores(date,end_date)
    schedule = games.games

    game_days = []
    for day in schedule.values():
        for game in day:
            game_days.append(game['boxscore'])
            
    season_games = []

    for i in game_days:
        temp = Boxscore(i).dataframe
        season_games.append(temp)

    df = pd.concat(season_games, axis = 0).reset_index()

    return df

# %%
playoffs_16=get_current_games(datetime(2016, 10, 4),datetime(2016, 11, 2))

# %%
playoffs_16
# Out:
#                index                         date              time  \
# 0   TOR/TOR201610040     Tuesday, October 4, 2016   8:08 p.m. Local
# 1   NYN/NYN201610050   Wednesday, October 5, 2016   8:10 p.m. Local
# 2   TEX/TEX201610060    Thursday, October 6, 2016   3:39 p.m. Local
# 3   CLE/CLE201610060    Thursday, October 6, 2016   8:08 p.m. Local
# 4   TEX/TEX201610070      Friday, October 7, 2016  12:08 p.m. Local
# 5   CLE/CLE201610070      Friday, October 7, 2016   4:39 p.m. Local
# 6   WAS/WAS201610070      Friday, October 7, 2016   5:38 p.m. Local
# 7   CHN/CHN201610070      Friday, October 7, 2016   8:16 p.m. Local
# 8   CHN/CHN201610080    Saturday, October 8, 2016   7:08 p.m. Local
# 9   WAS/WAS201610090      Sunday, October 9, 2016   1:08 p.m. Local
# 10  TOR/TOR201610090      Sunday, October 9, 2016   7:39 p.m. Local
# 11  LAN/LAN201610100     Monday, October 10, 2016   1:09 p.m. Local
# 12  BOS/BOS201610100     Monday, October 10, 2016   6:10 p.m. Local
# 13  SFN/SFN201610100     Monday, October 10, 2016   6:39 p.m. Local
# 14  LAN/LAN201610110    Tuesday, October 11, 2016   2:05 p.m. Local
# 15  SFN/SFN201610110    Tuesday, October 11, 2016   5:40 p.m. Local
# 16  WAS/WAS201610130   Thursday, October 13, 2016   8:09 p.m. Local
# 17  CLE/CLE201610140     Friday, October 14, 2016   8:08 p.m. Local
# 18  CLE/CLE201610150   Saturday, October 15, 2016   4:09 p.m. Local
# 19  CHN/CHN201610150   Saturday, October 15, 2016   7:09 p.m. Local
# 20  CHN/CHN201610160     Sunday, October 16, 2016   7:08 p.m. Local
# 21  TOR/TOR201610170     Monday, October 17, 2016   8:09 p.m. Local
# 22  TOR/TOR201610180    Tuesday, October 18, 2016   4:08 p.m. Local
# 23  LAN/LAN201610180    Tuesday, October 18, 2016   5:09 p.m. Local
# 24  TOR/TOR201610190  Wednesday, October 19, 2016   4:09 p.m. Local
# 25  LAN/LAN201610190  Wednesday, October 19, 2016   5:10 p.m. Local
# 26  LAN/LAN201610200   Thursday, October 20, 2016   8:09 p.m. Local
# 27  CHN/CHN201610220   Saturday, October 22, 2016   7:09 p.m. Local
# 28  CLE/CLE201610250    Tuesday, October 25, 2016   8:10 p.m. Local
# 29  CLE/CLE201610260  Wednesday, October 26, 2016   7:08 p.m. Local
# 30  CHN/CHN201610280     Friday, October 28, 2016   7:08 p.m. Local
# 31  CHN/CHN201610290   Saturday, October 29, 2016   7:09 p.m. Local
# 32  CHN/CHN201610300     Sunday, October 30, 2016   7:17 p.m. Local
# 33  CLE/CLE201611010    Tuesday, November 1, 2016   8:10 p.m. Local
# 34  CLE/CLE201611020  Wednesday, November 2, 2016   8:02 p.m. Local
#
#                            venue  attendance duration time_of_day winner  \
# 0                  Rogers Centre       49934     3:25       Night   Home
# 1                     Citi Field       44747     3:11       Night   Away
# 2   Globe Life Park in Arlington       47434     2:58         Day   Away
# 3              Progressive Field       37762     3:33       Night   Home
# 4   Globe Life Park in Arlington       48019     3:30         Day   Away
# 5              Progressive Field       37842     3:19         Day   Home
# 6                 Nationals Park       43915     3:46       Night   Away
# 7                  Wrigley Field       42148     2:30       Night   Home
# 8                  Wrigley Field       42392     3:03       Night   Home
# 9                 Nationals Park       43826     3:55         Day   Home
# 10                 Rogers Centre       49555     3:21       Night   Home
# 11                Dodger Stadium       53901     4:12         Day   Away
# 12                   Fenway Park       39530     3:41       Night   Away
# 13                     AT&T Park       43571     5:04       Night   Home
# 14                Dodger Stadium       49617     3:44         Day   Home
# 15                     AT&T Park       43166     3:25       Night   Away
# 16                Nationals Park       43936     4:32       Night   Away
# 17             Progressive Field       37727     2:44       Night   Home
# 18             Progressive Field       37870     2:44         Day   Home
# 19                 Wrigley Field       42376     3:37       Night   Home
# 20                 Wrigley Field       42384     2:45       Night   Away
# 21                 Rogers Centre       49507     3:23       Night   Away
# 22                 Rogers Centre       49142     3:01         Day   Home
# 23                Dodger Stadium       54269     3:18       Night   Home
# 24                 Rogers Centre       48800     2:37         Day   Away
# 25                Dodger Stadium       54449     3:58       Night   Away
# 26                Dodger Stadium       54449     4:16       Night   Away
# 27                 Wrigley Field       42386     2:36       Night   Home
# 28             Progressive Field       38091     3:37       Night   Home
# 29             Progressive Field       38172     4:04       Night   Away
# 30                 Wrigley Field       41703     3:33       Night   Away
# 31                 Wrigley Field       41706     3:16       Night   Away
# 32                 Wrigley Field       41711     3:27       Night   Home
# 33             Progressive Field       38116     3:29       Night   Away
# 34             Progressive Field       38104     4:28       Night   Away
#
#             winning_name winning_abbr  ... home_strikes_looking  \
# 0      Toronto Blue Jays          TOR  ...                   29
# 1   San Francisco Giants          SFG  ...                   20
# 2      Toronto Blue Jays          TOR  ...                   23
# 3      Cleveland Indians          CLE  ...                   24
# 4      Toronto Blue Jays          TOR  ...                   21
# 5      Cleveland Indians          CLE  ...                   21
# 6    Los Angeles Dodgers          LAD  ...                   27
# 7           Chicago Cubs          CHC  ...                   20
# 8           Chicago Cubs          CHC  ...                   28
# 9   Washington Nationals          WSN  ...                   31
# 10     Toronto Blue Jays          TOR  ...                   26
# 11  Washington Nationals          WSN  ...                   25
# 12     Cleveland Indians          CLE  ...                   35
# 13  San Francisco Giants          SFG  ...                   24
# 14   Los Angeles Dodgers          LAD  ...                   13
# 15          Chicago Cubs          CHC  ...                   18
# 16   Los Angeles Dodgers          LAD  ...                   21
# 17     Cleveland Indians          CLE  ...                   17
# 18     Cleveland Indians          CLE  ...                   18
# 19          Chicago Cubs          CHC  ...                   23
# 20   Los Angeles Dodgers          LAD  ...                   23
# 21     Cleveland Indians          CLE  ...                   31
# 22     Toronto Blue Jays          TOR  ...                   25
# 23   Los Angeles Dodgers          LAD  ...                   26
# 24     Cleveland Indians          CLE  ...                   24
# 25          Chicago Cubs          CHC  ...                   29
# 26          Chicago Cubs          CHC  ...                   19
# 27          Chicago Cubs          CHC  ...                   20
# 28     Cleveland Indians          CLE  ...                   31
# 29          Chicago Cubs          CHC  ...                   33
# 30     Cleveland Indians          CLE  ...                   17
# 31     Cleveland Indians          CLE  ...                   19
# 32          Chicago Cubs          CHC  ...                   29
# 33          Chicago Cubs          CHC  ...                   24
# 34          Chicago Cubs          CHC  ...                   32
#
#    home_grounded_balls  home_fly_balls  home_line_drives  \
# 0                   10              16                 4
# 1                    8              16                 4
# 2                    9              14                 3
# 3                    6              14                 8
# 4                   11              22                13
# 5                   13              12                 6
# 6                    6              19                 9
# 7                    7              10                 4
# 8                    8              19                 8
# 9                    7              10                 4
# 10                  10              18                 6
# 11                   7              17                 7
# 12                  11              14                 7
# 13                  26              15                11
# 14                  13               7                 1
# 15                  16              10                 5
# 16                   7              13                 6
# 17                  11              12                 4
# 18                  15               7                 5
# 19                   6              22                10
# 20                   8              11                 3
# 21                   9              15                 8
# 22                  10              15                 8
# 23                   9              17                 7
# 24                  10              13                 4
# 25                  12              11                 3
# 26                  14              15                 8
# 27                   7              16                 7
# 28                   8              16                 7
# 29                   7              12                 5
# 30                  15              10                 4
# 31                  10              15                 5
# 32                   6              11                 7
# 33                   8              13                 9
# 34                  16              16                11
#
#     home_unknown_bat_type  home_game_score  home_inherited_runners  \
# 0                       0               62                       1
# 1                       0               80                       0
# 2                       0               20                       1
# 3                       0               46                       0
# 4                       0               40                       0
# 5                       0               75                       2
# 6                       0               51                       0
# 7                       0               77                       0
# 8                       0               45                       2
# 9                       0               39                       4
# 10                      0               40                       2
# 11                      0               35                       4
# 12                      0               45                       0
# 13                      0               44                       0
# 14                      0               49                       8
# 15                      0               80                       6
# 16                      0               63                       7
# 17                      0               65                       0
# 18                      0               63                       1
# 19                      0               62                       5
# 20                      0               59                       2
# 21                      0               48                       2
# 22                      0               67                       0
# 23                      0               72                       1
# 24                      0               59                       0
# 25                      0               39                       2
# 26                      0               55                       6
# 27                      0               80                       1
# 28                      0               73                       1
# 29                      0               41                       5
# 30                      0               55                       4
# 31                      0               53                       4
# 32                      0               61                       1
# 33                      0               20                       4
# 34                      0               34                       5
#
#     home_inherited_score  home_win_probability_by_pitcher  \
# 0                      0                            0.715
# 1                      0                            0.075
# 2                      0                           -0.315
# 3                      0                            0.295
# 4                      0                           -0.194
# 5                      0                            0.252
# 6                      0                            0.066
# 7                      0                            0.711
# 8                      0                            0.277
# 9                      0                            0.257
# 10                     2                            0.117
# 11                     1                           -0.237
# 12                     0                           -0.045
# 13                     0                            0.273
# 14                     3                            0.037
# 15                     4                           -0.605
# 16                     3                           -0.105
# 17                     0                            0.610
# 18                     0                            0.674
# 19                     2                            0.046
# 20                     0                            0.339
# 21                     1                           -0.120
# 22                     0                            0.413
# 23                     0                            0.355
# 24                     0                           -0.019
# 25                     2                           -0.361
# 26                     3                           -0.197
# 27                     0                            0.275
# 28                     0                            0.421
# 29                     1                           -0.145
# 30                     0                            0.305
# 31                     2                           -0.243
# 32                     0                            0.485
# 33                     3                           -0.318
# 34                     0                           -0.511
#
#     home_base_out_runs_saved
# 0                        3.7
# 1                        1.3
# 2                       -5.1
# 3                        1.0
# 4                       -0.1
# 5                        5.0
# 6                        0.6
# 7                        4.5
# 8                        2.5
# 9                        2.6
# 10                      -0.8
# 11                      -3.7
# 12                       0.8
# 13                       1.2
# 14                      -0.7
# 15                      -1.7
# 16                       0.6
# 17                       5.0
# 18                       4.0
# 19                       0.5
# 20                       3.5
# 21                       0.7
# 22                       3.7
# 23                       4.3
# 24                       1.7
# 25                      -5.7
# 26                      -3.7
# 27                       4.5
# 28                       5.0
# 29                      -0.0
# 30                       3.5
# 31                      -2.5
# 32                       2.5
# 33                      -4.0
# 34                      -2.5
#
# [35 rows x 82 columns]

# %%
#playoffs_16.to_csv('raw_playoffs_2016.csv')

# %% [markdown]
# # Data Exploration

# %%
df=pd.read_csv('./raw_playoffs_2016.csv').drop('Unnamed: 0',axis=1)

# %%
df.columns
# Out:
# Index(['index', 'date', 'time', 'venue', 'attendance', 'duration',
#        'time_of_day', 'winner', 'winning_name', 'winning_abbr', 'losing_name',
#        'losing_abbr', 'away_at_bats', 'away_runs', 'away_hits', 'away_rbi',
#        'away_earned_runs', 'away_bases_on_balls', 'away_strikeouts',
#        'away_plate_appearances', 'away_batting_average',
#        'away_on_base_percentage', 'away_slugging_percentage',
#        'away_on_base_plus', 'away_pitches', 'away_strikes',
#        'away_win_probability_for_offensive_player',
#        'away_average_leverage_index', 'away_win_probability_added',
#        'away_win_probability_subtracted', 'away_base_out_runs_added',
#        'away_putouts', 'away_assists', 'away_innings_pitched',
#        'away_home_runs', 'away_strikes_by_contact', 'away_strikes_swinging',
#        'away_strikes_looking', 'away_grounded_balls', 'away_fly_balls',
#        'away_line_drives', 'away_unknown_bat_type', 'away_game_score',
#        'away_inherited_runners', 'away_inherited_score',
#        'away_win_probability_by_pitcher', 'away_base_out_runs_saved',
#        'home_at_bats', 'home_runs', 'home_hits', 'home_rbi',
#        'home_earned_runs', 'home_bases_on_balls', 'home_strikeouts',
#        'home_plate_appearances', 'home_batting_average',
#        'home_on_base_percentage', 'home_slugging_percentage',
#        'home_on_base_plus', 'home_pitches', 'home_strikes',
#        'home_win_probability_for_offensive_player',
#        'home_average_leverage_index', 'home_win_probability_added',
#        'home_win_probability_subtracted', 'home_base_out_runs_added',
#        'home_putouts', 'home_assists', 'home_innings_pitched',
#        'home_home_runs', 'home_strikes_by_contact', 'home_strikes_swinging',
#        'home_strikes_looking', 'home_grounded_balls', 'home_fly_balls',
#        'home_line_drives', 'home_unknown_bat_type', 'home_game_score',
#        'home_inherited_runners', 'home_inherited_score',
#        'home_win_probability_by_pitcher', 'home_base_out_runs_saved'],
#       dtype='object')

# %%
df.head()
# Out:
#               index                        date              time  \
# 0  TOR/TOR201610040    Tuesday, October 4, 2016   8:08 p.m. Local
# 1  NYN/NYN201610050  Wednesday, October 5, 2016   8:10 p.m. Local
# 2  TEX/TEX201610060   Thursday, October 6, 2016   3:39 p.m. Local
# 3  CLE/CLE201610060   Thursday, October 6, 2016   8:08 p.m. Local
# 4  TEX/TEX201610070     Friday, October 7, 2016  12:08 p.m. Local
#
#                           venue  attendance duration time_of_day winner  \
# 0                 Rogers Centre       49934     3:25       Night   Home
# 1                    Citi Field       44747     3:11       Night   Away
# 2  Globe Life Park in Arlington       47434     2:58         Day   Away
# 3             Progressive Field       37762     3:33       Night   Home
# 4  Globe Life Park in Arlington       48019     3:30         Day   Away
#
#            winning_name winning_abbr  ... home_strikes_looking  \
# 0     Toronto Blue Jays          TOR  ...                   29
# 1  San Francisco Giants          SFG  ...                   20
# 2     Toronto Blue Jays          TOR  ...                   23
# 3     Cleveland Indians          CLE  ...                   24
# 4     Toronto Blue Jays          TOR  ...                   21
#
#   home_grounded_balls  home_fly_balls  home_line_drives  \
# 0                  10              16                 4
# 1                   8              16                 4
# 2                   9              14                 3
# 3                   6              14                 8
# 4                  11              22                13
#
#    home_unknown_bat_type  home_game_score  home_inherited_runners  \
# 0                      0               62                       1
# 1                      0               80                       0
# 2                      0               20                       1
# 3                      0               46                       0
# 4                      0               40                       0
#
#    home_inherited_score  home_win_probability_by_pitcher  \
# 0                     0                            0.715
# 1                     0                            0.075
# 2                     0                           -0.315
# 3                     0                            0.295
# 4                     0                           -0.194
#
#    home_base_out_runs_saved
# 0                       3.7
# 1                       1.3
# 2                      -5.1
# 3                       1.0
# 4                      -0.1
#
# [5 rows x 82 columns]

# %%
#set date to datetime
df.date=pd.to_datetime(df.date)

# %%
#Set date as index
df.set_index(df.date,inplace=True)

# %%
#Get rid of whitespace
for column in df.columns:
    column.strip()

# %%
#drop no longer needed columns
df.drop(['index'],axis=1,inplace=True)

# %%
#drop date column as it is now in index
df.drop(['date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                         time                         venue  attendance  \
# date
# 2016-10-04   8:08 p.m. Local                 Rogers Centre       49934
# 2016-10-05   8:10 p.m. Local                    Citi Field       44747
# 2016-10-06   3:39 p.m. Local  Globe Life Park in Arlington       47434
# 2016-10-06   8:08 p.m. Local             Progressive Field       37762
# 2016-10-07  12:08 p.m. Local  Globe Life Park in Arlington       48019
#
#            duration time_of_day winner          winning_name winning_abbr  \
# date
# 2016-10-04     3:25       Night   Home     Toronto Blue Jays          TOR
# 2016-10-05     3:11       Night   Away  San Francisco Giants          SFG
# 2016-10-06     2:58         Day   Away     Toronto Blue Jays          TOR
# 2016-10-06     3:33       Night   Home     Cleveland Indians          CLE
# 2016-10-07     3:30         Day   Away     Toronto Blue Jays          TOR
#
#                   losing_name losing_abbr  ...  home_strikes_looking  \
# date                                       ...
# 2016-10-04  Baltimore Orioles         BAL  ...                    29
# 2016-10-05      New York Mets         NYM  ...                    20
# 2016-10-06      Texas Rangers         TEX  ...                    23
# 2016-10-06     Boston Red Sox         BOS  ...                    24
# 2016-10-07      Texas Rangers         TEX  ...                    21
#
#             home_grounded_balls  home_fly_balls  home_line_drives  \
# date
# 2016-10-04                   10              16                 4
# 2016-10-05                    8              16                 4
# 2016-10-06                    9              14                 3
# 2016-10-06                    6              14                 8
# 2016-10-07                   11              22                13
#
#             home_unknown_bat_type  home_game_score  home_inherited_runners  \
# date
# 2016-10-04                      0               62                       1
# 2016-10-05                      0               80                       0
# 2016-10-06                      0               20                       1
# 2016-10-06                      0               46                       0
# 2016-10-07                      0               40                       0
#
#             home_inherited_score  home_win_probability_by_pitcher  \
# date
# 2016-10-04                     0                            0.715
# 2016-10-05                     0                            0.075
# 2016-10-06                     0                           -0.315
# 2016-10-06                     0                            0.295
# 2016-10-07                     0                           -0.194
#
#             home_base_out_runs_saved
# date
# 2016-10-04                       3.7
# 2016-10-05                       1.3
# 2016-10-06                      -5.1
# 2016-10-06                       1.0
# 2016-10-07                      -0.1
#
# [5 rows x 80 columns]

# %%
#Put home and away winners in own dataframes
Home = df[(df['winner'] == 'Home')] 
Away= df[(df['winner'] == 'Away')]

# %%
#indians home and away wins in own df as example of what will be done to every team
cle_home_wins=Home[(Home['winning_abbr'] == 'CLE')]
cle_away_wins=Away[(Away['winning_abbr']=='CLE')]

# %%
#indians total wins concated together
cle_wins=pd.concat([cle_home_wins,cle_away_wins])

# %%
cle_wins.winning_abbr.value_counts()
# Out:
# CLE    10
# Name: winning_abbr, dtype: int64

# %%
#CLE home and away losses
cle_home_loss=Home[(Home['losing_abbr'] == 'CLE')]
cle_away_loss=Away[(Away['losing_abbr']=='CLE')]

# %%
#combine dataframes of cle losses
cle_loss=pd.concat([cle_home_loss,cle_away_loss])

# %%
cle_loss.losing_abbr.value_counts()
# Out:
# CLE    5
# Name: losing_abbr, dtype: int64

# %%
#combine to make complete 2016 playoffs
cle_16=pd.concat([cle_wins,cle_loss])

# %%
cle_16.head()
# Out:
#                        time              venue  attendance duration  \
# date
# 2016-10-06  8:08 p.m. Local  Progressive Field       37762     3:33
# 2016-10-07  4:39 p.m. Local  Progressive Field       37842     3:19
# 2016-10-14  8:08 p.m. Local  Progressive Field       37727     2:44
# 2016-10-15  4:09 p.m. Local  Progressive Field       37870     2:44
# 2016-10-25  8:10 p.m. Local  Progressive Field       38091     3:37
#
#            time_of_day winner       winning_name winning_abbr  \
# date
# 2016-10-06       Night   Home  Cleveland Indians          CLE
# 2016-10-07         Day   Home  Cleveland Indians          CLE
# 2016-10-14       Night   Home  Cleveland Indians          CLE
# 2016-10-15         Day   Home  Cleveland Indians          CLE
# 2016-10-25       Night   Home  Cleveland Indians          CLE
#
#                   losing_name losing_abbr  ...  home_strikes_looking  \
# date                                       ...
# 2016-10-06     Boston Red Sox         BOS  ...                    24
# 2016-10-07     Boston Red Sox         BOS  ...                    21
# 2016-10-14  Toronto Blue Jays         TOR  ...                    17
# 2016-10-15  Toronto Blue Jays         TOR  ...                    18
# 2016-10-25       Chicago Cubs         CHC  ...                    31
#
#             home_grounded_balls  home_fly_balls  home_line_drives  \
# date
# 2016-10-06                    6              14                 8
# 2016-10-07                   13              12                 6
# 2016-10-14                   11              12                 4
# 2016-10-15                   15               7                 5
# 2016-10-25                    8              16                 7
#
#             home_unknown_bat_type  home_game_score  home_inherited_runners  \
# date
# 2016-10-06                      0               46                       0
# 2016-10-07                      0               75                       2
# 2016-10-14                      0               65                       0
# 2016-10-15                      0               63                       1
# 2016-10-25                      0               73                       1
#
#             home_inherited_score  home_win_probability_by_pitcher  \
# date
# 2016-10-06                     0                            0.295
# 2016-10-07                     0                            0.252
# 2016-10-14                     0                            0.610
# 2016-10-15                     0                            0.674
# 2016-10-25                     0                            0.421
#
#             home_base_out_runs_saved
# date
# 2016-10-06                       1.0
# 2016-10-07                       5.0
# 2016-10-14                       5.0
# 2016-10-15                       4.0
# 2016-10-25                       5.0
#
# [5 rows x 80 columns]

# %% [markdown]
# ### Team Reg Season Function walkthrough outside to find potential bugs

# %%
#Rename columns to avoid deletetion later
df_16=df.rename(columns={'home_home_runs':'home_HR','away_home_runs':'away_HR'})

# %%
df_16.columns
# Out:
# Index(['time', 'venue', 'attendance', 'duration', 'time_of_day', 'winner',
#        'winning_name', 'winning_abbr', 'losing_name', 'losing_abbr',
#        'away_at_bats', 'away_runs', 'away_hits', 'away_rbi',
#        'away_earned_runs', 'away_bases_on_balls', 'away_strikeouts',
#        'away_plate_appearances', 'away_batting_average',
#        'away_on_base_percentage', 'away_slugging_percentage',
#        'away_on_base_plus', 'away_pitches', 'away_strikes',
#        'away_win_probability_for_offensive_player',
#        'away_average_leverage_index', 'away_win_probability_added',
#        'away_win_probability_subtracted', 'away_base_out_runs_added',
#        'away_putouts', 'away_assists', 'away_innings_pitched', 'away_HR',
#        'away_strikes_by_contact', 'away_strikes_swinging',
#        'away_strikes_looking', 'away_grounded_balls', 'away_fly_balls',
#        'away_line_drives', 'away_unknown_bat_type', 'away_game_score',
#        'away_inherited_runners', 'away_inherited_score',
#        'away_win_probability_by_pitcher', 'away_base_out_runs_saved',
#        'home_at_bats', 'home_runs', 'home_hits', 'home_rbi',
#        'home_earned_runs', 'home_bases_on_balls', 'home_strikeouts',
#        'home_plate_appearances', 'home_batting_average',
#        'home_on_base_percentage', 'home_slugging_percentage',
#        'home_on_base_plus', 'home_pitches', 'home_strikes',
#        'home_win_probability_for_offensive_player',
#        'home_average_leverage_index', 'home_win_probability_added',
#        'home_win_probability_subtracted', 'home_base_out_runs_added',
#        'home_putouts', 'home_assists', 'home_innings_pitched', 'home_HR',
#        'home_strikes_by_contact', 'home_strikes_swinging',
#        'home_strikes_looking', 'home_grounded_balls', 'home_fly_balls',
#        'home_line_drives', 'home_unknown_bat_type', 'home_game_score',
#        'home_inherited_runners', 'home_inherited_score',
#        'home_win_probability_by_pitcher', 'home_base_out_runs_saved'],
#       dtype='object')

# %%
#Isolate Home winners and away winners into their own df
Home = df_16[(df_16['winner'] == 'Home')] 
Away= df_16[(df_16['winner'] == 'Away')]

# %%
#CLE home wins and losses isolated then combined to only have their stats from those games
home_wins=Home[(Home['winning_abbr'] == 'CLE')]
home_loss=Away[(Away['losing_abbr'] == 'CLE')]
home_games= pd.concat([home_wins,home_loss])
home_offense = home_games.filter(like = 'home')

# %%
#CLE away wins and losses isolated then combined to only have their stats from those games
away_wins=Away[(Away['winning_abbr']=='CLE')]
away_loss=Home[(Home['losing_abbr']=='CLE')]
away_games= pd.concat([away_wins,away_loss])
away_offense = away_games.filter(like = 'away')

# %%
#Get rid of the words home/away
home_offense.columns = home_offense.columns.str.replace('home_','')
away_offense.columns = away_offense.columns.str.replace('away_','')

# %%
#home_offense.drop('away_runs',axis=1,inplace=True)

# %%
#Check to make sure that the columns are the same for both data frames
home_offense.columns==away_offense.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
#Combine dataframes to make one dataframe of all this teams stats
team_offense = pd.concat([home_offense, away_offense])

# %%
#From the teams given home games take the stats of the team they played against
home_games_opponents = home_games.filter(like = 'away')
away_games_opponents = away_games.filter(like = 'home')

# %%
#Get rid of the words home/away
home_games_opponents.columns = home_games_opponents.columns.str.replace('away_','')
away_games_opponents.columns = away_games_opponents.columns.str.replace('home_','')

# %%
#Combine to make dataframe of stats from all opponents 
team_opponents= pd.concat([home_games_opponents,away_games_opponents])

# %%
#Combine theirs and the opponents to make one full data frame for the team, put an Opp_ 
#prefix in front of opponent stats
team_full_check = pd.concat([team_offense, team_opponents.add_prefix('Opp_')], axis = 1)

# %%
team_full_check.head()
# Out:
#             at_bats  runs  hits  rbi  earned_runs  bases_on_balls  strikeouts  \
# date
# 2016-10-06       32     5    10    5         5.62               1          12
# 2016-10-07       32     6     9    6         5.62               3           8
# 2016-10-14       27     2     6    2         2.25               1           6
# 2016-10-15       28     2     4    2         2.25               2           6
# 2016-10-25       33     6    10    6         6.75               4           9
#
#             plate_appearances  batting_average  on_base_percentage  ...  \
# date                                                                ...
# 2016-10-06                 34            0.312               0.353  ...
# 2016-10-07                 36            0.281               0.333  ...
# 2016-10-14                 30            0.222               0.250  ...
# 2016-10-15                 30            0.143               0.200  ...
# 2016-10-25                 38            0.303               0.395  ...
#
#             Opp_strikes_looking  Opp_grounded_balls  Opp_fly_balls  \
# date
# 2016-10-06                   32                   8             14
# 2016-10-07                   29                   9             12
# 2016-10-14                   37                  13              8
# 2016-10-15                   30                  14              3
# 2016-10-25                   36                   2             17
#
#             Opp_line_drives  Opp_unknown_bat_type  Opp_game_score  \
# date
# 2016-10-06                5                     0              37
# 2016-10-07                4                     0              29
# 2016-10-14                5                     0              67
# 2016-10-15                1                     0              54
# 2016-10-25                7                     0              49
#
#             Opp_inherited_runners  Opp_inherited_score  \
# date
# 2016-10-06                    2.0                  1.0
# 2016-10-07                    4.0                  2.0
# 2016-10-14                    NaN                  NaN
# 2016-10-15                    0.0                  0.0
# 2016-10-25                    3.0                  2.0
#
#             Opp_win_probability_by_pitcher  Opp_base_out_runs_saved
# date
# 2016-10-06                          -0.206                     -0.6
# 2016-10-07                          -0.249                     -1.6
# 2016-10-14                           0.109                      2.4
# 2016-10-15                           0.173                      2.4
# 2016-10-25                          -0.079                     -1.6
#
# [5 rows x 70 columns]

# %% [markdown]
# I need to create a column that has the teams name in it all the way down, below I will try and make this column using the LAD as my example

# %%
#create name column and fill it with the new LAD variable made above
team_full_check =team_full_check.assign(name='CLE')

# %%
med_odds=pd.read_csv('../data/MLB__median_odds_2016.csv')

# %%
med_odds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Team         30 non-null     object
#  1   Median_odds  30 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 608.0+ bytes

# %%
med_odds.set_index('Team',inplace=True)

# %%
team_full_check.head()
# Out:
#             at_bats  runs  hits  rbi  earned_runs  bases_on_balls  strikeouts  \
# date
# 2016-10-06       32     5    10    5         5.62               1          12
# 2016-10-07       32     6     9    6         5.62               3           8
# 2016-10-14       27     2     6    2         2.25               1           6
# 2016-10-15       28     2     4    2         2.25               2           6
# 2016-10-25       33     6    10    6         6.75               4           9
#
#             plate_appearances  batting_average  on_base_percentage  ...  \
# date                                                                ...
# 2016-10-06                 34            0.312               0.353  ...
# 2016-10-07                 36            0.281               0.333  ...
# 2016-10-14                 30            0.222               0.250  ...
# 2016-10-15                 30            0.143               0.200  ...
# 2016-10-25                 38            0.303               0.395  ...
#
#             Opp_grounded_balls  Opp_fly_balls  Opp_line_drives  \
# date
# 2016-10-06                   8             14                5
# 2016-10-07                   9             12                4
# 2016-10-14                  13              8                5
# 2016-10-15                  14              3                1
# 2016-10-25                   2             17                7
#
#             Opp_unknown_bat_type  Opp_game_score  Opp_inherited_runners  \
# date
# 2016-10-06                     0              37                    2.0
# 2016-10-07                     0              29                    4.0
# 2016-10-14                     0              67                    NaN
# 2016-10-15                     0              54                    0.0
# 2016-10-25                     0              49                    3.0
#
#             Opp_inherited_score  Opp_win_probability_by_pitcher  \
# date
# 2016-10-06                  1.0                          -0.206
# 2016-10-07                  2.0                          -0.249
# 2016-10-14                  NaN                           0.109
# 2016-10-15                  0.0                           0.173
# 2016-10-25                  2.0                          -0.079
#
#             Opp_base_out_runs_saved  name
# date
# 2016-10-06                     -0.6   CLE
# 2016-10-07                     -1.6   CLE
# 2016-10-14                      2.4   CLE
# 2016-10-15                      2.4   CLE
# 2016-10-25                     -1.6   CLE
#
# [5 rows x 71 columns]

# %%
med_odds.loc['ARI','Median_odds']
# Out:
# 114.0

# %%
med_odds=med_odds.rename({'LOS':'LAD','CUB':'CHC','CWS':'CHW','KAN':'KCR','SDG':'SDP','SFO':'SFG','TAM':'TBR'})

# %%
team_full_check = team_full_check.groupby('name').mean().reset_index()

# %%
team_full_check
# Out:
#   name  at_bats  runs      hits       rbi  earned_runs  bases_on_balls  \
# 0  CLE     31.8   3.6  7.066667  3.266667     3.399333             2.6
#
#    strikeouts  plate_appearances  batting_average  ...  Opp_strikes_looking  \
# 0         9.2          35.466667            0.219  ...            27.733333
#
#    Opp_grounded_balls  Opp_fly_balls  Opp_line_drives  Opp_unknown_bat_type  \
# 0                10.2      13.933333              6.2                   0.0
#
#    Opp_game_score  Opp_inherited_runners  Opp_inherited_score  \
# 0       53.333333               2.142857             0.785714
#
#    Opp_win_probability_by_pitcher  Opp_base_out_runs_saved
# 0                        0.070133                     1.06
#
# [1 rows x 71 columns]

# %% [markdown]
# ### Build reusable Function

# %%
def team_regular_season(df,team,average=True,num=162):
    #Set year range for what games you want to access
    #Rename columns to avoid deletetion later
    df=df.rename(columns={'home_home_runs':'home_HR','away_home_runs':'away_HR'})
    
        #Get all the home winner and away winner games alone
    Home = df[(df['winner'] == 'Home')] 
    Away= df[(df['winner'] == 'Away')]
    
        #Get games where the team was the home team
    home_wins=Home[(Home['winning_abbr'] == team)]
    home_loss=Away[(Away['losing_abbr'] == team)]
    home_games= pd.concat([home_wins,home_loss])
    home_offense = home_games.filter(like = 'home')
    
      #Get games where the team was the away team
    away_wins=Away[(Away['winning_abbr']==team)]
    away_loss=Home[(Home['losing_abbr']==team)]
    away_games= pd.concat([away_wins,away_loss])
    away_offense = away_games.filter(like = 'away')
    
        # split the dataframes to only have the statistics of the given team
    home_offense.columns = home_offense.columns.str.replace('home_','')
    away_offense.columns = away_offense.columns.str.replace('away_','')
    
    #combine offensive stats into one df
    team_offense = pd.concat([home_offense, away_offense])
    
        # create oppposing team statistics from the given games
    home_games_opponents = home_games.filter(like = 'away')
    away_games_opponents = away_games.filter(like = 'home')
    
        # rename the columns from the opponent statistics dataframes
    home_games_opponents.columns = home_games_opponents.columns.str.replace('away_','')
    away_games_opponents.columns = away_games_opponents.columns.str.replace('home_','')
    
    team_opponents= pd.concat([home_games_opponents,away_games_opponents])
    
        # concat the team stats and the opponent stats to create a full picture of the team's season
    team_full = pd.concat([team_offense, team_opponents.add_prefix('Opp_')], axis = 1)
    team_full = team_full.assign(name=team)
    
    # Certain teams only played 161 games this season and therefor need different number
#     club_161=['DET','CLE','MIA','ATL']
#     if team in club_161:
#         num=161
#     else:
#         num=162
#     add= ((team,)*num)
#     team_full['name']= add

    
    
        # return either the season averages or the game by game statistics
    if average:
            team_full = team_full.groupby('name').mean().reset_index()
    
    team_full['median_odds']= med_odds.loc[team,'Median_odds']
    
    return team_full

# %%
#Check unique names
df.winning_abbr.unique()
# Out:
# array(['TOR', 'SFG', 'CLE', 'LAD', 'CHC', 'WSN'], dtype=object)

# %%
#Below examined that each teams abbr was working in the function including the 161 teams
dodgers_16=team_regular_season(df,'LAD')

# %% [markdown]
# ### Single Game Function Walkthrough to find/fix bugs

# %%
#create regular seasons using yankees and mets as our example
bos_16=team_regular_season(df,'BOS')
cle_16=team_regular_season(df,'CLE')

# %%
#Concat them as if they are playing against one another 
pd.concat([yanks_16, mets_16])
# Out:
#   name  at_bats  runs  hits  rbi  earned_runs  bases_on_balls  strikeouts  \
# 0  NYM       30     0     4    0          0.0               2           6
#
#    plate_appearances  batting_average  ...  Opp_grounded_balls  Opp_fly_balls  \
# 0                 32            0.133  ...                   9             10
#
#    Opp_line_drives  Opp_unknown_bat_type  Opp_game_score  \
# 0                2                     0              83
#
#    Opp_inherited_runners  Opp_inherited_score  Opp_win_probability_by_pitcher  \
# 0                    NaN                  NaN                           0.575
#
#    Opp_base_out_runs_saved  median_odds
# 0                      4.3       -123.0
#
# [1 rows x 72 columns]

# %%
#Try this as we may prefer it to all be in one row
pd.concat([bos_16.add_prefix('H_'), cle_16.add_prefix('A_')], axis = 1)
# Out:
#   H_name  H_at_bats    H_runs  H_hits     H_rbi  H_earned_runs  \
# 0    BOS  32.666667  2.333333     7.0  2.333333       2.333333
#
#    H_bases_on_balls  H_strikeouts  H_plate_appearances  H_batting_average  \
# 0          2.666667     10.333333                 36.0           0.207667
#
#    ...  A_Opp_grounded_balls  A_Opp_fly_balls  A_Opp_line_drives  \
# 0  ...                  10.2        13.933333                6.2
#
#    A_Opp_unknown_bat_type  A_Opp_game_score  A_Opp_inherited_runners  \
# 0                     0.0         53.333333                 2.142857
#
#    A_Opp_inherited_score  A_Opp_win_probability_by_pitcher  \
# 0               0.785714                          0.070133
#
#    A_Opp_base_out_runs_saved  A_median_odds
# 0                       1.06         -133.0
#
# [1 rows x 144 columns]

# %% [markdown]
# ### Build Reusable Function

# %%
def single_game(team1_name, team2_name,df=df):
    
    # from the Team abbreviations get a dataframe with the average seasonlong team statistics.
    team1 = team_regular_season(df,team1_name)
    team2 = team_regular_season(df,team2_name)
    
    #make the single game by concating those dataframes
    game = pd.concat([team1.add_prefix('H_'), team2.add_prefix('A_')], axis = 1)
    
    return game

# %% [markdown]
# ###  Create Season Function Walkthrough to Find Bugs

# %%
#df_16.drop(['index'],axis=1,inplace=True)

# %%
df_16
# Out:
#                         time                         venue  attendance  \
# date
# 2016-10-04   8:08 p.m. Local                 Rogers Centre       49934
# 2016-10-05   8:10 p.m. Local                    Citi Field       44747
# 2016-10-06   3:39 p.m. Local  Globe Life Park in Arlington       47434
# 2016-10-06   8:08 p.m. Local             Progressive Field       37762
# 2016-10-07  12:08 p.m. Local  Globe Life Park in Arlington       48019
# 2016-10-07   4:39 p.m. Local             Progressive Field       37842
# 2016-10-07   5:38 p.m. Local                Nationals Park       43915
# 2016-10-07   8:16 p.m. Local                 Wrigley Field       42148
# 2016-10-08   7:08 p.m. Local                 Wrigley Field       42392
# 2016-10-09   1:08 p.m. Local                Nationals Park       43826
# 2016-10-09   7:39 p.m. Local                 Rogers Centre       49555
# 2016-10-10   1:09 p.m. Local                Dodger Stadium       53901
# 2016-10-10   6:10 p.m. Local                   Fenway Park       39530
# 2016-10-10   6:39 p.m. Local                     AT&T Park       43571
# 2016-10-11   2:05 p.m. Local                Dodger Stadium       49617
# 2016-10-11   5:40 p.m. Local                     AT&T Park       43166
# 2016-10-13   8:09 p.m. Local                Nationals Park       43936
# 2016-10-25     3:37       Night   Home     Cleveland Indians          CLE
# 2016-10-26     4:04       Night   Away          Chicago Cubs          CHC
# 2016-10-28     3:33       Night   Away     Cleveland Indians          CLE
# 2016-10-29     3:16       Night   Away     Cleveland Indians          CLE
# 2016-10-30     3:27       Night   Home          Chicago Cubs          CHC
# 2016-11-01     3:29       Night   Away          Chicago Cubs          CHC
# 2016-11-02     4:28       Night   Away          Chicago Cubs          CHC
#
#                      losing_name losing_abbr  ...  home_strikes_looking  \
# date                                          ...
# 2016-10-04     Baltimore Orioles         BAL  ...                    29
# 2016-10-05         New York Mets         NYM  ...                    20
# 2016-10-06         Texas Rangers         TEX  ...                    23
# 2016-10-06        Boston Red Sox         BOS  ...                    24
# 2016-10-07         Texas Rangers         TEX  ...                    21
# 2016-10-07        Boston Red Sox         BOS  ...                    21
# 2016-10-07  Washington Nationals         WSN  ...                    27
# 2016-10-07  San Francisco Giants         SFG  ...                    20
# 2016-10-08  San Francisco Giants         SFG  ...                    28
# 2016-10-09   Los Angeles Dodgers         LAD  ...                    31
# 2016-10-09         Texas Rangers         TEX  ...                    26
# 2016-10-10   Los Angeles Dodgers         LAD  ...                    25
# 2016-10-10        Boston Red Sox         BOS  ...                    35
# 2016-10-10          Chicago Cubs         CHC  ...                    24
# 2016-10-11  Washington Nationals         WSN  ...                    13
# 2016-10-11  San Francisco Giants         SFG  ...                    18
# 2016-10-13  Washington Nationals         WSN  ...                    21
# 2016-10-14     Toronto Blue Jays         TOR  ...                    17
# 2016-10-15     Toronto Blue Jays         TOR  ...                    18
# 2016-10-15   Los Angeles Dodgers         LAD  ...                    23
# 2016-10-16          Chicago Cubs         CHC  ...                    23
# 2016-10-17     Toronto Blue Jays         TOR  ...                    31
# 2016-10-18     Cleveland Indians         CLE  ...                    25
# 2016-10-18          Chicago Cubs         CHC  ...                    26
# 2016-10-19     Toronto Blue Jays         TOR  ...                    24
# 2016-10-19   Los Angeles Dodgers         LAD  ...                    29
# 2016-10-20   Los Angeles Dodgers         LAD  ...                    19
# 2016-10-22   Los Angeles Dodgers         LAD  ...                    20
# 2016-10-25          Chicago Cubs         CHC  ...                    31
# 2016-10-26     Cleveland Indians         CLE  ...                    33
# 2016-10-28          Chicago Cubs         CHC  ...                    17
# 2016-10-29          Chicago Cubs         CHC  ...                    19
# 2016-10-30     Cleveland Indians         CLE  ...                    29
# 2016-11-01     Cleveland Indians         CLE  ...                    24
# 2016-11-02     Cleveland Indians         CLE  ...                    32
#
#             home_grounded_balls  home_fly_balls  home_line_drives  \
# date
# 2016-10-04                   10              16                 4
# 2016-10-05                    8              16                 4
# 2016-10-06                    9              14                 3
# 2016-10-06                    6              14                 8
# 2016-10-07                   11              22                13
# 2016-10-07                   13              12                 6
# 2016-10-07                    6              19                 9
# 2016-10-07                    7              10                 4
# 2016-10-08                    8              19                 8
# 2016-10-09                    7              10                 4
# 2016-10-09                   10              18                 6
# 2016-10-10                    7              17                 7
# 2016-10-10                   11              14                 7
# 2016-10-25                     0                            0.421
# 2016-10-26                     1                           -0.145
# 2016-10-28                     0                            0.305
# 2016-10-29                     2                           -0.243
# 2016-10-30                     0                            0.485
# 2016-11-01                     3                           -0.318
# 2016-11-02                     0                           -0.511
#
#             home_base_out_runs_saved
# date
# 2016-10-04                       3.7
# 2016-10-05                       1.3
# 2016-10-06                      -5.1
# 2016-10-06                       1.0
# 2016-10-07                      -0.1
# 2016-10-07                       5.0
# 2016-10-07                       0.6
# 2016-10-07                       4.5
# 2016-10-08                       2.5
# 2016-10-09                       2.6
# 2016-10-09                      -0.8
# 2016-10-10                      -3.7
# 2016-10-10                       0.8
# 2016-10-10                       1.2
# 2016-10-11                      -0.7
# 2016-10-11                      -1.7
# 2016-10-13                       0.6
# 2016-10-14                       5.0
# 2016-10-15                       4.0
# 2016-10-15                       0.5
# 2016-10-16                       3.5
# 2016-10-17                       0.7
# 2016-10-18                       3.7
# 2016-10-18                       4.3
# 2016-10-19                       1.7
# 2016-10-19                      -5.7
# 2016-10-20                      -3.7
# 2016-10-22                       4.5
# 2016-10-25                       5.0
# 2016-10-26                      -0.0
# 2016-10-28                       3.5
# 2016-10-29                      -2.5
# 2016-10-30                       2.5
# 2016-11-01                      -4.0
# 2016-11-02                      -2.5
#
# [35 rows x 80 columns]

# %%
#Reset the index
df_16.reset_index(inplace=True)

# %%
# season_df for 2016 season
#season_df = df_16[df_16['date'] >= '2016-4-3']

# %% [markdown]
# In the cells below I will try and alter the dataframes so rather than tellin us the winning and losing name it will return the names of the home or away team

# %%
#Get home winners and Away winners in their own dataframe
Home =df_16 [(df_16['winner'] == 'Home')] 
Away= df_16[(df_16['winner'] == 'Away')]

# %%
#Rename columns in the home win from winner and loser to home and away
Home=Home.rename(columns={'winning_abbr':'home_abbr','winning_name':'home_name','losing_name':'away_name',
                         'losing_abbr':'away_abbr'})

# %%
#Rename columns in the away win from winner and loser to home and away
Away= Away.rename(columns={'winning_abbr':'away_abbr','winning_name':'away_name','losing_name':'home_name',
                         'losing_abbr':'home_abbr'})

# %%
#Concat these to make season_df now the same but with these new column names
df_16= pd.concat([Home,Away])

# %%
#Get Home and away alone once again
Home = df_16[(df_16['winner'] == 'Home')] 
Away= df_16[(df_16['winner'] == 'Away')]

# %%
#Create a winning abbreviation column
Home['winning_abbr']= Home['home_abbr']
Away['winning_abbr']= Away['away_abbr']
# Out:
# <ipython-input-255-12da05963abd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Home['winning_abbr']= Home['home_abbr']
# <ipython-input-255-12da05963abd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Away['winning_abbr']= Away['away_abbr']

# %%
#Concat to update season_df
df_16=pd.concat([Home,Away])

# %%
#make it sorted in order of date
df_16=df_16.sort_values('date')

# %%
df_16.head()
# Out:
#     index       date             time                         venue  \
# 0       0 2016-10-04  8:08 p.m. Local                 Rogers Centre
# 17      1 2016-10-05  8:10 p.m. Local                    Citi Field
# 18      2 2016-10-06  3:39 p.m. Local  Globe Life Park in Arlington
# 1       3 2016-10-06  8:08 p.m. Local             Progressive Field
# 20      6 2016-10-07  5:38 p.m. Local                Nationals Park
#
#     attendance duration time_of_day winner             home_name home_abbr  \
# 0        49934     3:25       Night   Home     Toronto Blue Jays       TOR
# 17       44747     3:11       Night   Away         New York Mets       NYM
# 18       47434     2:58         Day   Away         Texas Rangers       TEX
# 1        37762     3:33       Night   Home     Cleveland Indians       CLE
# 20       43915     3:46       Night   Away  Washington Nationals       WSN
#
#     ... home_grounded_balls home_fly_balls  home_line_drives  \
# 0   ...                  10             16                 4
# 17  ...                   8             16                 4
# 18  ...                   9             14                 3
# 1   ...                   6             14                 8
# 20  ...                   6             19                 9
#
#     home_unknown_bat_type  home_game_score  home_inherited_runners  \
# 0                       0               62                       1
# 17                      0               80                       0
# 18                      0               20                       1
# 1                       0               46                       0
# 20                      0               51                       0
#
#     home_inherited_score  home_win_probability_by_pitcher  \
# 0                      0                            0.715
# 17                     0                            0.075
# 18                     0                           -0.315
# 1                      0                            0.295
# 20                     0                            0.066
#
#     home_base_out_runs_saved  winning_abbr
# 0                        3.7           TOR
# 17                       1.3           SFG
# 18                      -5.1           TOR
# 1                        1.0           CLE
# 20                       0.6           LAD
#
# [5 rows x 83 columns]

# %%
# create a list with the two teams, home team always first, the season, and the day number of the game
matchups = list(zip(df_16.home_abbr, df_16.away_abbr, df_16.date, df_16.winning_abbr))

# %%
#Check matchups
matchups[-2]
# Out:
# ('CLE', 'CHC', Timestamp('2016-11-01 00:00:00'), 'CHC')

# %%
#empty season_games list
season_games = []

# %%
med_odds=med_odds.rename({'WAS':'WSN'})

# %%
med_odds.loc['WSN','Median_odds']
# Out:
# -155.0

# %%
#loop through matchups and create single games for each matchup using that function, then append to season games
for team in matchups:
        game = single_game(team[0], team[1],df)
        season_games.append(game)

# %%
#create df_prep as a example for what will hopefully happen in a function
df_prep = pd.concat(season_games, axis = 0)

# %%
#reset_index
df_prep.reset_index(inplace = True, drop = True)

# %%
df_prep
# Out:
#    H_name  H_at_bats    H_runs    H_hits     H_rbi  H_earned_runs  \
# 0     TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 1     NYM  30.000000  0.000000  4.000000  0.000000       0.000000
# 2     TEX  34.333333  3.333333  7.000000  3.333333       3.133333
# 3     CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 4     WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 5     TEX  34.333333  3.333333  7.000000  3.333333       3.133333
# 6     CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 7     CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 8     CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 9     TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 10    WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 11    BOS  32.666667  2.333333  7.000000  2.333333       2.333333
# 12    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 13    SFG  34.600000  3.200000  8.200000  3.200000       2.900000
# 14    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 15    SFG  34.600000  3.200000  8.200000  3.200000       2.900000
# 16    WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 17    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 18    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 19    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 20    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 21    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 22    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 23    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 24    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 25    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 26    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 27    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 28    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 29    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 30    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 31    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 32    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 33    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 34    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
#
#     H_bases_on_balls  H_strikeouts  H_plate_appearances  H_batting_average  \
# 0           2.777778      8.777778            36.888889           0.225222
# 1           2.000000      6.000000            32.000000           0.133000
# 2           2.333333      7.333333            36.666667           0.193667
# 3           2.600000      9.200000            35.466667           0.219000
# 4           4.400000     12.600000            39.400000           0.251600
# 5           2.333333      7.333333            36.666667           0.193667
# 6           2.600000      9.200000            35.466667           0.219000
# 7           2.705882      8.941176            37.941176           0.226824
# 8           2.705882      8.941176            37.941176           0.226824
# 9           2.777778      8.777778            36.888889           0.225222
# 10          4.400000     12.600000            39.400000           0.251600
# 20                   1.072727         -148.0
# 21                   1.060000         -133.0
# 22                   1.060000         -133.0
# 23                   0.141176         -176.0
# 24                   0.141176         -176.0
# 25                   1.060000         -133.0
# 26                   0.141176         -176.0
# 27                   1.072727         -148.0
# 28                   0.141176         -176.0
# 29                   0.141176         -176.0
# 30                   1.060000         -133.0
# 31                   1.060000         -133.0
# 32                   1.060000         -133.0
# 33                   0.141176         -176.0
# 34                   0.141176         -176.0
#
# [35 rows x 144 columns]

# %%
#Create new column where it will have a 1 if home team won and 0 if away team won
df_prep['home_win'] = np.where(df_16.home_abbr ==df_16.winning_abbr,
                  [1],
                  [0])

# %%
#Examine our new column
df_prep.home_win.value_counts(normalize=True)
# Out:
# 0    0.514286
# 1    0.485714
# Name: home_win, dtype: float64

# %%
df_prep
# Out:
#    H_name  H_at_bats    H_runs    H_hits     H_rbi  H_earned_runs  \
# 0     TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 1     NYM  30.000000  0.000000  4.000000  0.000000       0.000000
# 2     TEX  34.333333  3.333333  7.000000  3.333333       3.133333
# 3     CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 4     WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 5     TEX  34.333333  3.333333  7.000000  3.333333       3.133333
# 6     CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 7     CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 8     CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 9     TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 10    WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 11    BOS  32.666667  2.333333  7.000000  2.333333       2.333333
# 12    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 13    SFG  34.600000  3.200000  8.200000  3.200000       2.900000
# 14    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 15    SFG  34.600000  3.200000  8.200000  3.200000       2.900000
# 16    WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 17    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 18    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 19    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 20    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 21    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 22    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 23    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 24    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 25    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 26    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 27    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 28    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 29    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 30    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 31    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 32    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 33    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 34    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
#
#     H_bases_on_balls  H_strikeouts  H_plate_appearances  H_batting_average  \
# 0           2.777778      8.777778            36.888889           0.225222
# 1           2.000000      6.000000            32.000000           0.133000
# 2           2.333333      7.333333            36.666667           0.193667
# 3           2.600000      9.200000            35.466667           0.219000
# 4           4.400000     12.600000            39.400000           0.251600
# 5           2.333333      7.333333            36.666667           0.193667
# 6           2.600000      9.200000            35.466667           0.219000
# 7           2.705882      8.941176            37.941176           0.226824
# 8           2.705882      8.941176            37.941176           0.226824
# 9           2.777778      8.777778            36.888889           0.225222
# 10          4.400000     12.600000            39.400000           0.251600
# 11          2.666667     10.333333            36.000000           0.207667
# 12          3.363636      7.818182            36.454545           0.212091
# 13          2.400000      8.200000            38.400000           0.231200
# 14          3.363636      7.818182            36.454545           0.212091
# 15          2.400000      8.200000            38.400000           0.231200
# 16          4.400000     12.600000            39.400000           0.251600
# 17          2.600000      9.200000            35.466667           0.219000
# 18          2.705882      8.941176            37.941176           0.226824
# 19          2.600000      9.200000            35.466667           0.219000
# 20          2.705882      8.941176            37.941176           0.226824
# 21          2.777778      8.777778            36.888889           0.225222
# 22          2.777778      8.777778            36.888889           0.225222
# 23          3.363636      7.818182            36.454545           0.212091
# 24          3.363636      7.818182            36.454545           0.212091
# 25          2.777778      8.777778            36.888889           0.225222
# 26          3.363636      7.818182            36.454545           0.212091
# 27          2.705882      8.941176            37.941176           0.226824
# 28          2.600000      9.200000            35.466667           0.219000
_Opp_win_probability_by_pitcher  A_Opp_base_out_runs_saved  \
# 0                           0.715000                   3.700000
# 1                           0.146200                   1.340000
# 2                           0.153111                   0.955556
# 3                           0.334333                   2.600000
# 4                           0.088545                   1.072727
# 5                           0.153111                   0.955556
# 6                           0.334333                   2.600000
# 7                           0.146200                   1.340000
# 8                           0.146200                   1.340000
# 9                           0.202667                   1.666667
# 10                          0.088545                   1.072727
# 11                          0.070133                   1.060000
# 12                          0.103600                  -0.420000
# 13                          0.006588                   0.141176
# 14                          0.103600                  -0.420000
# 15                          0.006588                   0.141176
# 16                          0.088545                   1.072727
# 17                          0.153111                   0.955556
# 18                          0.088545                   1.072727
# 19                          0.153111                   0.955556
# 20                          0.088545                   1.072727
# 21                          0.070133                   1.060000
# 22                          0.070133                   1.060000
# 23                          0.006588                   0.141176
# 24                          0.006588                   0.141176
# 25                          0.070133                   1.060000
# 26                          0.006588                   0.141176
# 27                          0.088545                   1.072727
# 28                          0.006588                   0.141176
# 29                          0.006588                   0.141176
# 30                          0.070133                   1.060000
# 31                          0.070133                   1.060000
# 32                          0.070133                   1.060000
# 33                          0.006588                   0.141176
# 34                          0.006588                   0.141176
#
#     A_median_odds  home_win
# 0          -107.0         1
# 1          -124.0         0
# 2          -141.0         0
# 3          -130.0         1
# 4          -148.0         0
# 5          -141.0         0
# 6          -130.0         1
# 7          -124.0         1
# 8          -124.0         1
# 9           101.0         1
# 10         -148.0         1
# 11         -133.0         0
# 12         -155.0         0
# 13         -176.0         1
# 14         -155.0         1
# 15         -176.0         0
# 16         -148.0         0
# 17         -141.0         1
# 18         -148.0         1
# 19         -141.0         1
# 20         -148.0         0
# 21         -133.0         0
# 22         -133.0         1
# 23         -176.0         1
# 24         -176.0         0
# 25         -133.0         0
# 26         -176.0         0
# 27         -148.0         1
# 28         -176.0         1
# 29         -176.0         0
# 30         -133.0         0
# 31         -133.0         0
# 32         -133.0         1
# 33         -176.0         0
# 34         -176.0         0
#
# [35 rows x 145 columns]

# %% [markdown]
# ***

# %%
df_16.drop(['index'],axis=1,inplace=True)

# %%
#df_16.set_index('date',inplace=True)

# %%
df_16.head()
# Out:
#         date             time                         venue  attendance  \
# 0 2016-10-04  8:08 p.m. Local                 Rogers Centre       49934
# 1 2016-10-05  8:10 p.m. Local                    Citi Field       44747
# 2 2016-10-06  3:39 p.m. Local  Globe Life Park in Arlington       47434
# 3 2016-10-06  8:08 p.m. Local             Progressive Field       37762
# 6 2016-10-07  5:38 p.m. Local                Nationals Park       43915
#
#   duration time_of_day winner             home_name home_abbr  \
# 0     3:25       Night   Home     Toronto Blue Jays       TOR
# 1     3:11       Night   Away         New York Mets       NYM
# 2     2:58         Day   Away         Texas Rangers       TEX
# 3     3:33       Night   Home     Cleveland Indians       CLE
# 6     3:46       Night   Away  Washington Nationals       WSN
#
#               away_name  ... home_grounded_balls  home_fly_balls  \
# 0     Baltimore Orioles  ...                  10              16
# 1  San Francisco Giants  ...                   8              16
# 2     Toronto Blue Jays  ...                   9              14
# 3        Boston Red Sox  ...                   6              14
# 6   Los Angeles Dodgers  ...                   6              19
#
#    home_line_drives  home_unknown_bat_type  home_game_score  \
# 0                 4                      0               62
# 1                 4                      0               80
# 2                 3                      0               20
# 3                 8                      0               46
# 6                 9                      0               51
#
#    home_inherited_runners  home_inherited_score  \
# 0                       1                     0
# 1                       0                     0
# 2                       1                     0
# 3                       0                     0
# 6                       0                     0
#
#    home_win_probability_by_pitcher  home_base_out_runs_saved  winning_abbr
# 0                            0.715                       3.7           TOR
# 1                            0.075                       1.3           SFG
# 2                           -0.315                      -5.1           TOR
# 3                            0.295                       1.0           CLE
# 6                            0.066                       0.6           LAD
#
# [5 rows x 82 columns]

# %%
df_16.set_index('date',inplace=True)

# %% [markdown]
# ### Create Season Dataframe

# %%
def create_season_df(df,date):
    
    #Reset the index
    df.reset_index(inplace=True)
  
    # create a DataFrame for the season we are looking for
    # season_df for whatever season you are looking for
    season_df = df[df['date'] >= date]
    #reset index
    #season_df.reset_index(inplace = True)
    
    #Get home winners and Away winners in their own dataframe
    Home = df[(df['winner'] == 'Home')] 
    Away= df[(df['winner'] == 'Away')]
    
    #Rename columns in the home win from winner and loser to home and away
    Home=Home.rename(columns={'winning_abbr':'home_abbr','winning_name':'home_name','losing_name':'away_name',
                         'losing_abbr':'away_abbr'})
    
    #Rename columns in the away win from winner and loser to home and away
    Away= Away.rename(columns={'winning_abbr':'away_abbr','winning_name':'away_name','losing_name':'home_name',
                         'losing_abbr':'home_abbr'})
    
    #Concat these to make season_df now the same but with these new column names
    df= pd.concat([Home,Away])
    
    #Get Home and away alone once again
    Home = df[(df['winner'] == 'Home')] 
    Away= df[(df['winner'] == 'Away')]
    
    #Create a winning abbreviation column
    Home['winning_abbr']= Home['home_abbr']
    Away['winning_abbr']= Away['away_abbr']
    
    #Concat to update season_df
    df=pd.concat([Home,Away])
    
    #order it by date again
    df=season_df.sort_values('date')
    
    
    # create a list with the two teams, home team always first, the season, and the day number of the game
    matchups = list(zip(df.home_abbr, df.away_abbr, df.date, df.winning_abbr))
    
    season_games = [] 

    #loop through matchups and create single games for each matchup using that function, then append to season games
    for team in matchups:
        game = single_game(team[0], team[1],df)
        season_games.append(game)
    
    # from the season games list concatenate all the outputted DataFrames and insert the location
    # of the winner (home(1), away(0))
    df = pd.concat(season_games, axis = 0)
    #reset_index
    df.reset_index(inplace = True, drop = True)
    #Create new column where it will have a 1 if home team won and 0 if away team won
    df['home_win'] = np.where(season_df.home_abbr ==season_df.winning_abbr,
                  [1],
                  [0])
                       
    return df

# %%
season_2016=create_season_df(df_16,'2016-10-4')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-262-c054d20631a3> in <module>
# ----> 1 season_2016=create_season_df(df_16,'2016-10-4')
#
# <ipython-input-261-b3a25c7c186b> in create_season_df(df, date)
#      23
#      24     #Concat these to make season_df now the same but with these new column names
# ---> 25     df= pd.concat([Home,Away])
#      26
#      27     #Get Home and away alone once again
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     285     )
#     286
# --> 287     return op.get_result()
#     288
#     289
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     500                 mgrs_indexers.append((obj._mgr, indexers))
#     501
# --> 502             new_data = concatenate_block_managers(
#     503                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy,
#     504             )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      82         blocks.append(b)
#      83
# ---> 84     return BlockManager(blocks, axes)
#      85
#      86
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     147
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#     151         # Populate known_consolidate, blknos, and blklocs lazily
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     326                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     327         if len(self.items) != tot_items:
# --> 328             raise AssertionError(
#     329                 "Number of manager items must equal union of "
#     330                 f"block items\n# manager items: {len(self.items)}, # "
#
# AssertionError: Number of manager items must equal union of block items
# # manager items: 83, # tot_items: 84

# %%
df_prep.head(10)
# Out:
#   H_name  H_at_bats    H_runs    H_hits     H_rbi  H_earned_runs  \
# 0    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 1    NYM  30.000000  0.000000  4.000000  0.000000       0.000000
# 2    TEX  34.333333  3.333333  7.000000  3.333333       3.133333
# 3    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 4    WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 5    TEX  34.333333  3.333333  7.000000  3.333333       3.133333
# 6    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 7    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 8    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 9    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
#
#    H_bases_on_balls  H_strikeouts  H_plate_appearances  H_batting_average  \
# 0          2.777778      8.777778            36.888889           0.225222
# 1          2.000000      6.000000            32.000000           0.133000
# 2          2.333333      7.333333            36.666667           0.193667
# 3          2.600000      9.200000            35.466667           0.219000
# 4          4.400000     12.600000            39.400000           0.251600
# 5          2.333333      7.333333            36.666667           0.193667
# 6          2.600000      9.200000            35.466667           0.219000
# 7          2.705882      8.941176            37.941176           0.226824
# 8          2.705882      8.941176            37.941176           0.226824
# 9          2.777778      8.777778            36.888889           0.225222
#
#    ...  A_Opp_fly_balls  A_Opp_line_drives  A_Opp_unknown_bat_type  \
# 0  ...        16.000000           4.000000                     0.0
# 1  ...        15.400000           6.400000                     0.0
# 2  ...        13.555556           5.666667                     0.0
# 3  ...        13.000000           7.000000                     0.0
# 4  ...        15.909091           7.000000                     0.0
# 5  ...        13.555556           5.666667                     0.0
# 6  ...        13.000000           7.000000                     0.0
# 7  ...        15.400000           6.400000                     0.0
# 8  ...        15.400000           6.400000                     0.0
# 9  ...        19.000000           5.666667                     0.0
#
#    A_Opp_game_score  A_Opp_inherited_runners  A_Opp_inherited_score  \
# 0         62.000000                 1.000000               0.000000
# 1         59.200000                 1.800000               0.800000
# 2         48.333333                 2.000000               0.222222
# 3         58.333333                 1.333333               0.666667
# 4         54.272727                 2.727273               0.636364
# 5         48.333333                 2.000000               0.222222
# 6         58.333333                 1.333333               0.666667
# 7         59.200000                 1.800000               0.800000
# 8         59.200000                 1.800000               0.800000
# 9         55.333333                 2.666667               1.000000
#
#    A_Opp_win_probability_by_pitcher  A_Opp_base_out_runs_saved  A_median_odds  \
# 0                          0.715000                   3.700000         -107.0
# 1                          0.146200                   1.340000         -124.0
# 2                          0.153111                   0.955556         -141.0
# 3                          0.334333                   2.600000         -130.0
# 4                          0.088545                   1.072727         -148.0
# 5                          0.153111                   0.955556         -141.0
# 6                          0.334333                   2.600000         -130.0
# 7                          0.146200                   1.340000         -124.0
# 8                          0.146200                   1.340000         -124.0
# 9                          0.202667                   1.666667          101.0
#
#    home_win
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0
# 5         0
# 6         1
# 7         1
# 8         1
# 9         1
#
# [10 rows x 145 columns]

# %%
#season_2016.to_csv('data/Season_2016_with_odds.csv')

# %% [markdown]
# ## Create a new column called fav win

# %%
playoffs_2016=df_prep

# %%
playoffs_2016
# Out:
#    H_name  H_at_bats    H_runs    H_hits     H_rbi  H_earned_runs  \
# 0     TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 1     NYM  30.000000  0.000000  4.000000  0.000000       0.000000
# 2     TEX  34.333333  3.333333  7.000000  3.333333       3.133333
# 3     CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 4     WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 5     TEX  34.333333  3.333333  7.000000  3.333333       3.133333
# 6     CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 7     CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 8     CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 9     TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 10    WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 11    BOS  32.666667  2.333333  7.000000  2.333333       2.333333
# 12    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 13    SFG  34.600000  3.200000  8.200000  3.200000       2.900000
# 14    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 15    SFG  34.600000  3.200000  8.200000  3.200000       2.900000
# 16    WSN  33.400000  4.800000  8.400000  4.800000       4.924000
# 17    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 18    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 19    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 20    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 21    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 22    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 23    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 24    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 25    TOR  33.888889  3.888889  7.777778  3.666667       3.390000
# 26    LAD  31.818182  3.272727  6.909091  3.272727       3.409091
# 27    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 28    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 29    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 30    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 31    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 32    CHC  34.529412  4.411765  8.058824  4.294118       3.898824
# 33    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
# 34    CLE  31.800000  3.600000  7.066667  3.266667       3.399333
#
#     H_bases_on_balls  H_strikeouts  H_plate_appearances  H_batting_average  \
# 0           2.777778      8.777778            36.888889           0.225222
# 1           2.000000      6.000000            32.000000           0.133000
# 2           2.333333      7.333333            36.666667           0.193667
# 3           2.600000      9.200000            35.466667           0.219000
# 4           4.400000     12.600000            39.400000           0.251600
# 5           2.333333      7.333333            36.666667           0.193667
# 6           2.600000      9.200000            35.466667           0.219000
# 7           2.705882      8.941176            37.941176           0.226824
# 8           2.705882      8.941176            37.941176           0.226824
# 9           2.777778      8.777778            36.888889           0.225222
# 10          4.400000     12.600000            39.400000           0.251600
# 11          2.666667     10.333333            36.000000           0.207667
# 12          3.363636      7.818182            36.454545           0.212091
# 13          2.400000      8.200000            38.400000           0.231200
# 14          3.363636      7.818182            36.454545           0.212091
# 15          2.400000      8.200000            38.400000           0.231200
# 16          4.400000     12.600000            39.400000           0.251600
# 17          2.600000      9.200000            35.466667           0.219000
# 18          2.705882      8.941176            37.941176           0.226824
# 19          2.600000      9.200000            35.466667           0.219000
# 20          2.705882      8.941176            37.941176           0.226824
# 21          2.777778      8.777778            36.888889           0.225222
# 22          2.777778      8.777778            36.888889           0.225222
# 23          3.363636      7.818182            36.454545           0.212091
# 24          3.363636      7.818182            36.454545           0.212091
# 25          2.777778      8.777778            36.888889           0.225222
# 26          3.363636      7.818182            36.454545           0.212091
# 27          2.705882      8.941176            37.941176           0.226824
# 28          2.600000      9.200000            35.466667           0.219000
# 29          2.600000      9.200000            35.466667           0.219000
# 30          2.705882      8.941176            37.941176           0.226824
# 28         52.588235                 2.125000               0.812500
# 29         52.588235                 2.125000               0.812500
# 30         53.333333                 2.142857               0.785714
# 31         53.333333                 2.142857               0.785714
# 32         53.333333                 2.142857               0.785714
# 33         52.588235                 2.125000               0.812500
# 34         52.588235                 2.125000               0.812500
#
#     A_Opp_win_probability_by_pitcher  A_Opp_base_out_runs_saved  \
# 0                           0.715000                   3.700000
# 1                           0.146200                   1.340000
# 2                           0.153111                   0.955556
# 3                           0.334333                   2.600000
# 4                           0.088545                   1.072727
# 5                           0.153111                   0.955556
# 6                           0.334333                   2.600000
# 7                           0.146200                   1.340000
# 8                           0.146200                   1.340000
# 9                           0.202667                   1.666667
# 10                          0.088545                   1.072727
# 11                          0.070133                   1.060000
# 12                          0.103600                  -0.420000
# 13                          0.006588                   0.141176
# 14                          0.103600                  -0.420000
# 15                          0.006588                   0.141176
# 16                          0.088545                   1.072727
# 17                          0.153111                   0.955556
# 18                          0.088545                   1.072727
# 19                          0.153111                   0.955556
# 20                          0.088545                   1.072727
# 21                          0.070133                   1.060000
# 22                          0.070133                   1.060000
# 23                          0.006588                   0.141176
# 24                          0.006588                   0.141176
# 25                          0.070133                   1.060000
# 26                          0.006588                   0.141176
# 27                          0.088545                   1.072727
# 28                          0.006588                   0.141176
# 29                          0.006588                   0.141176
# 30                          0.070133                   1.060000
# 31                          0.070133                   1.060000
# 32                          0.070133                   1.060000
# 33                          0.006588                   0.141176
# 34                          0.006588                   0.141176
#
#     A_median_odds  home_win
# 0          -107.0         1
# 1          -124.0         0
# 2          -141.0         0
# 3          -130.0         1
# 4          -148.0         0
# 5          -141.0         0
# 6          -130.0         1
# 7          -124.0         1
# 8          -124.0         1
# 9           101.0         1
# 10         -148.0         1
# 11         -133.0         0
# 12         -155.0         0
# 13         -176.0         1
# 14         -155.0         1
# 15         -176.0         0
# 16         -148.0         0
# 17         -141.0         1
# 18         -148.0         1
# 19         -141.0         1
# 20         -148.0         0
# 21         -133.0         0
# 22         -133.0         1
# 23         -176.0         1
# 24         -176.0         0
# 25         -133.0         0
# 26         -176.0         0
# 27         -148.0         1
# 28         -176.0         1
# 29         -176.0         0
# 30         -133.0         0
# 31         -133.0         0
# 32         -133.0         1
# 33         -176.0         0
# 34         -176.0         0
#
# [35 rows x 145 columns]

# %%
for i,row in playoffs_2016.iterrows():
    fav_win_list=[]
    if row.H_median_odds < row.A_median_odds:
    #& row.home_win==1:
        fav_win_list.append(1)
    elif row.A_median_odds <row.H_median_odds: 
    #& row.home_win==0:
        fav_win_list.append(1)
    else:
        fav_win_list.append(0)

# %%
playoffs_2016['home_fav'] = np.where(playoffs_2016.H_median_odds < playoffs_2016.A_median_odds , 1, 0)

# %%
playoffs_2016['fav_win']=np.where(playoffs_2016.home_fav==playoffs_2016.home_win,1,0)

# %%
playoffs_2016.fav_win.value_counts(normalize=True)
# Out:
# 1    0.628571
# 0    0.371429
# Name: fav_win, dtype: float64

# %%
playoffs_2016.to_csv('../data/Playoffs_2016.csv')
