# %% [markdown]
# # Data Exploration

# %%
#import relevant Packages
import pandas as pd
import numpy as np
from sportsipy.mlb.boxscore import Boxscore
from sportsipy.mlb.boxscore import Boxscores

# %%
from datetime import datetime
from sportsipy.mlb.boxscore import Boxscores

# %%
# Function to return games in certain time range
def get_current_games(date,end_date,end_week=None):
    
    games = Boxscores(date,end_date)
    schedule = games.games

    game_days = []
    for day in schedule.values():
        for game in day:
            game_days.append(game['boxscore'])
            
    season_games = []

    for i in game_days:
        temp = Boxscore(i).dataframe
        season_games.append(temp)

    df = pd.concat(season_games, axis = 0).reset_index()

    return df

# %%
playoffs_21=get_current_games(datetime(2021, 10, 5),datetime(2021, 11, 2))

# %%
df=playoffs_21

# %%
df.columns
# Out:
# Index(['time', 'venue', 'attendance', 'duration', 'time_of_day', 'winner',
#        'winning_name', 'winning_abbr', 'losing_name', 'losing_abbr',
#        'away_at_bats', 'away_runs', 'away_hits', 'away_rbi',
#        'away_earned_runs', 'away_bases_on_balls', 'away_strikeouts',
#        'away_plate_appearances', 'away_batting_average',
#        'away_on_base_percentage', 'away_slugging_percentage',
#        'away_on_base_plus', 'away_pitches', 'away_strikes',
#        'away_win_probability_for_offensive_player',
#        'away_average_leverage_index', 'away_win_probability_added',
#        'away_win_probability_subtracted', 'away_base_out_runs_added',
#        'away_putouts', 'away_assists', 'away_innings_pitched',
#        'away_home_runs', 'away_strikes_by_contact', 'away_strikes_swinging',
#        'away_strikes_looking', 'away_grounded_balls', 'away_fly_balls',
#        'away_line_drives', 'away_unknown_bat_type', 'away_game_score',
#        'away_inherited_runners', 'away_inherited_score',
#        'away_win_probability_by_pitcher', 'away_base_out_runs_saved',
#        'home_at_bats', 'home_runs', 'home_hits', 'home_rbi',
#        'home_earned_runs', 'home_bases_on_balls', 'home_strikeouts',
#        'home_plate_appearances', 'home_batting_average',
#        'home_on_base_percentage', 'home_slugging_percentage',
#        'home_on_base_plus', 'home_pitches', 'home_strikes',
#        'home_win_probability_for_offensive_player',
#        'home_average_leverage_index', 'home_win_probability_added',
#        'home_win_probability_subtracted', 'home_base_out_runs_added',
#        'home_putouts', 'home_assists', 'home_innings_pitched',
#        'home_home_runs', 'home_strikes_by_contact', 'home_strikes_swinging',
#        'home_strikes_looking', 'home_grounded_balls', 'home_fly_balls',
#        'home_line_drives', 'home_unknown_bat_type', 'home_game_score',
#        'home_inherited_runners', 'home_inherited_score',
#        'home_win_probability_by_pitcher', 'home_base_out_runs_saved'],
#       dtype='object')

# %%
df.head()
# Out:
#                        time             venue  attendance duration  \
# date
# 2021-10-05  8:08 p.m. Local       Fenway Park       38324     3:13
# 2021-10-06  5:10 p.m. Local    Dodger Stadium       53193     4:15
# 2021-10-07  3:07 p.m. Local  Minute Maid Park       40497     3:34
# 2021-10-07  8:07 p.m. Local   Tropicana Field       27419     3:06
# 2021-10-08  1:07 p.m. Local  Minute Maid Park       41315     3:52
#
#            time_of_day winner         winning_name winning_abbr  \
# date
# 2021-10-05       Night   Home       Boston Red Sox          BOS
# 2021-10-06       Night   Home  Los Angeles Dodgers          LAD
# 2021-10-07         Day   Home       Houston Astros          HOU
# 2021-10-07       Night   Home       Tampa Bay Rays          TBR
# 2021-10-08         Day   Home       Houston Astros          HOU
#
#                     losing_name losing_abbr  ...  home_strikes_looking  \
# date                                         ...
# 2021-10-05     New York Yankees         NYY  ...                    23
# 2021-10-06  St. Louis Cardinals         STL  ...                    26
# 2021-10-07    Chicago White Sox         CHW  ...                    21
# 2021-10-07       Boston Red Sox         BOS  ...                    17
# 2021-10-08    Chicago White Sox         CHW  ...                    23
#
#             home_grounded_balls  home_fly_balls  home_line_drives  \
# date
# 2021-10-05                    8              11                 4
# 2021-10-06                   10              15                 9
# 2021-10-07                   13              13                 7
# 2021-10-07                    9              15                 5
# 2021-10-08                    9              16                 7
#
#             home_unknown_bat_type  home_game_score  home_inherited_runners  \
# date
# 2021-10-05                      0               64                       1
# 2021-10-06                      0               54                       3
# 2021-10-07                      0               70                       2
# 2021-10-07                      0               60                       0
# 2021-10-08                      0               38                       2
#
#             home_inherited_score  home_win_probability_by_pitcher  \
# date
# 2021-10-05                     0                            0.323
# 2021-10-06                     0                            0.573
# 2021-10-07                     0                            0.266
# 2021-10-07                     0                            0.309
# 2021-10-08                     2                           -0.039
#
#             home_base_out_runs_saved
# date
# 2021-10-05                       3.1
# 2021-10-06                       3.6
# 2021-10-07                       3.7
# 2021-10-07                       4.3
# 2021-10-08                       0.7
#
# [5 rows x 80 columns]

# %%
#set date to datetime
df.date=pd.to_datetime(df.date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-a496f005486a> in <module>
#       1 #set date to datetime
# ----> 2 df.date=pd.to_datetime(df.date)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'date'

# %%
#Set date as index
df.set_index(df.date,inplace=True)

# %%
#Get rid of whitespace
for column in df.columns:
    column.strip()

# %%
#drop no longer needed columns
df.drop(['index'],axis=1,inplace=True)

# %%
#drop date column as it is now in index
df.drop(['date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                        time             venue  attendance duration  \
# date
# 2021-10-05  8:08 p.m. Local       Fenway Park       38324     3:13
# 2021-10-06  5:10 p.m. Local    Dodger Stadium       53193     4:15
# 2021-10-07  3:07 p.m. Local  Minute Maid Park       40497     3:34
# 2021-10-07  8:07 p.m. Local   Tropicana Field       27419     3:06
# 2021-10-08  1:07 p.m. Local  Minute Maid Park       41315     3:52
#
#            time_of_day winner         winning_name winning_abbr  \
# date
# 2021-10-05       Night   Home       Boston Red Sox          BOS
# 2021-10-06       Night   Home  Los Angeles Dodgers          LAD
# 2021-10-07         Day   Home       Houston Astros          HOU
# 2021-10-07       Night   Home       Tampa Bay Rays          TBR
# 2021-10-08         Day   Home       Houston Astros          HOU
#
#                     losing_name losing_abbr  ...  home_strikes_looking  \
# date                                         ...
# 2021-10-05     New York Yankees         NYY  ...                    23
# 2021-10-06  St. Louis Cardinals         STL  ...                    26
# 2021-10-07    Chicago White Sox         CHW  ...                    21
# 2021-10-07       Boston Red Sox         BOS  ...                    17
# 2021-10-08    Chicago White Sox         CHW  ...                    23
#
#             home_grounded_balls  home_fly_balls  home_line_drives  \
# date
# 2021-10-05                    8              11                 4
# 2021-10-06                   10              15                 9
# 2021-10-07                   13              13                 7
# 2021-10-07                    9              15                 5
# 2021-10-08                    9              16                 7
#
#             home_unknown_bat_type  home_game_score  home_inherited_runners  \
# date
# 2021-10-05                      0               64                       1
# 2021-10-06                      0               54                       3
# 2021-10-07                      0               70                       2
# 2021-10-07                      0               60                       0
# 2021-10-08                      0               38                       2
#
#             home_inherited_score  home_win_probability_by_pitcher  \
# date
# 2021-10-05                     0                            0.323
# 2021-10-06                     0                            0.573
# 2021-10-07                     0                            0.266
# 2021-10-07                     0                            0.309
# 2021-10-08                     2                           -0.039
#
#             home_base_out_runs_saved
# date
# 2021-10-05                       3.1
# 2021-10-06                       3.6
# 2021-10-07                       3.7
# 2021-10-07                       4.3
# 2021-10-08                       0.7
#
# [5 rows x 80 columns]

# %%
df
# Out:
#                        time                  venue  attendance duration  \
# date
# 2021-10-05  8:08 p.m. Local            Fenway Park       38324     3:13
# 2021-10-06  5:10 p.m. Local         Dodger Stadium       53193     4:15
# 2021-10-07  3:07 p.m. Local       Minute Maid Park       40497     3:34
# 2021-10-07  8:07 p.m. Local        Tropicana Field       27419     3:06
# 2021-10-08  1:07 p.m. Local       Minute Maid Park       41315     3:52
# 2021-10-08  3:37 p.m. Local  American Family Field       40852     3:00
# 2021-10-08  7:02 p.m. Local        Tropicana Field       37616     3:56
# 2021-10-08  6:37 p.m. Local            Oracle Park       41934     2:39
# 2021-10-09  4:07 p.m. Local  American Family Field       43812     3:23
# 2021-10-09  6:07 p.m. Local            Oracle Park       42275     3:27
# 2021-10-10  4:07 p.m. Local            Fenway Park       37224     5:14
# 2021-10-10  7:07 p.m. Local  Guaranteed Rate Field       40288     4:27
# 2021-10-11  1:07 p.m. Local            Truist Park       41479     3:20
# 2021-10-11  7:07 p.m. Local            Fenway Park       38447     3:25
# 2021-10-11  6:37 p.m. Local         Dodger Stadium       53299     3:08
# 2021-10-12  1:07 p.m. Local  Guaranteed Rate Field       40170     4:32
# 2021-10-22       Night   Home        Houston Astros          HOU
# 2021-10-23       Night   Home        Atlanta Braves          ATL
# 2021-10-26       Night   Away        Atlanta Braves          ATL
# 2021-10-27       Night   Home        Houston Astros          HOU
# 2021-10-29       Night   Home        Atlanta Braves          ATL
# 2021-10-30       Night   Home        Atlanta Braves          ATL
# 2021-10-31       Night   Away        Houston Astros          HOU
# 2021-11-02       Night   Away        Atlanta Braves          ATL
#
#                      losing_name losing_abbr  ...  home_strikes_looking  \
# date                                          ...
# 2021-10-05      New York Yankees         NYY  ...                    23
# 2021-10-06   St. Louis Cardinals         STL  ...                    26
# 2021-10-07     Chicago White Sox         CHW  ...                    21
# 2021-10-07        Boston Red Sox         BOS  ...                    17
# 2021-10-08     Chicago White Sox         CHW  ...                    23
# 2021-10-08        Atlanta Braves         ATL  ...                    18
# 2021-10-08        Tampa Bay Rays         TBR  ...                    20
# 2021-10-08   Los Angeles Dodgers         LAD  ...                    19
# 2021-10-09     Milwaukee Brewers         MIL  ...                    28
# 2021-10-09  San Francisco Giants         SFG  ...                    17
# 2021-10-10        Tampa Bay Rays         TBR  ...                    27
# 2021-10-10        Houston Astros         HOU  ...                    23
# 2021-10-11     Milwaukee Brewers         MIL  ...                    20
# 2021-10-11        Tampa Bay Rays         TBR  ...                    21
# 2021-10-11   Los Angeles Dodgers         LAD  ...                    18
# 2021-10-12     Chicago White Sox         CHW  ...                    25
# 2021-10-12     Milwaukee Brewers         MIL  ...                    19
# 2021-10-12  San Francisco Giants         SFG  ...                    20
# 2021-10-14  San Francisco Giants         SFG  ...                    25
# 2021-10-15        Boston Red Sox         BOS  ...                    25
# 2021-10-16        Houston Astros         HOU  ...                    21
# 2021-10-16   Los Angeles Dodgers         LAD  ...                    18
# 2021-10-17   Los Angeles Dodgers         LAD  ...                    18
# 2021-10-18        Houston Astros         HOU  ...                    23
# 2021-10-19        Atlanta Braves         ATL  ...                    28
# 2021-10-19        Boston Red Sox         BOS  ...                    23
# 2021-10-20        Boston Red Sox         BOS  ...                    15
# 2021-10-20   Los Angeles Dodgers         LAD  ...                    17
# 2021-10-21        Atlanta Braves         ATL  ...                    28
# 2021-10-22        Boston Red Sox         BOS  ...                    26
# 2021-10-23   Los Angeles Dodgers         LAD  ...                    22
# 2021-10-26        Houston Astros         HOU  ...                    21
# 2021-10-27        Atlanta Braves         ATL  ...                    21
# 2021-10-29        Houston Astros         HOU  ...                    15
# 2021-10-30        Houston Astros         HOU  ...                    18
# 2021-10-31        Atlanta Braves         ATL  ...                    26
# 2021-11-02        Houston Astros         HOU  ...                    28
#
#             home_grounded_balls  home_fly_balls  home_line_drives  \
# date
# 2021-10-05                    8              11                 4
# 2021-10-06                   10              15                 9
# 2021-10-07                   13              13                 7
# 2021-10-07                    9              15                 5
# 2021-10-08                    9              16                 7
# 2021-10-08                    9               9                 2
# 2021-10-08                   11              11                 2
# 2021-10-08                    9              13                 4
# 2021-10-09                    5              13                 8
# 2021-10-09                    4              20                 6
# 2021-10-10                   17              25                12
# 2021-10-10                   13              15                 9
# 2021-10-11                    6              17                 5
# 2021-10-23                     0                            0.364
# 2021-10-26                     1                           -0.236
# 2021-10-27                     0                            0.161
# 2021-10-29                     0                            0.684
# 2021-10-30                     1                            0.435
# 2021-10-31                     2                           -0.495
# 2021-11-02                     0                           -0.247
#
#             home_base_out_runs_saved
# date
# 2021-10-05                       3.1
# 2021-10-06                       3.6
# 2021-10-07                       3.7
# 2021-10-07                       4.3
# 2021-10-08                       0.7
# 2021-10-08                       3.7
# 2021-10-08                      -9.7
# 2021-10-08                       4.5
# 2021-10-09                       1.7
# 2021-10-09                      -4.5
# 2021-10-10                       3.4
# 2021-10-10                      -1.3
# 2021-10-11                       4.9
# 2021-10-11                       0.1
# 2021-10-11                       3.6
# 2021-10-12                      -5.3
# 2021-10-12                       0.9
# 2021-10-12                       2.6
# 2021-10-14                       2.5
# 2021-10-15                       0.7
# 2021-10-16                      -4.3
# 2021-10-16                       2.9
# 2021-10-17                       0.9
# 2021-10-18                       2.1
# 2021-10-19                      -0.4
# 2021-10-19                      -3.9
# 2021-10-20                      -3.9
# 2021-10-20                      -4.4
# 2021-10-21                       2.6
# 2021-10-22                       4.7
# 2021-10-23                       2.9
# 2021-10-26                      -1.3
# 2021-10-27                       2.7
# 2021-10-29                       4.9
# 2021-10-30                       2.9
# 2021-10-31                      -4.1
# 2021-11-02                      -2.3
#
# [37 rows x 80 columns]

# %%
#Put home and away winners in own dataframes
Home = df[(df['winner'] == 'Home')] 
Away= df[(df['winner'] == 'Away')]

# %%
#Atl home and away wins in own df as example of what will be done to every team
atl_home_wins=Home[(Home['winning_abbr'] == 'ATL')]
atl_away_wins=Away[(Away['winning_abbr']=='ATL')]

# %%
#indians total wins concated together
atl_wins=pd.concat([atl_home_wins,atl_away_wins])

# %%
atl_wins.winning_abbr.value_counts()
# Out:
# ATL    11
# Name: winning_abbr, dtype: int64

# %%
#atl home and away losses
atl_home_loss=Home[(Home['losing_abbr'] == 'ATL')]
atl_away_loss=Away[(Away['losing_abbr']=='ATL')]

# %%
#combine dataframes of cle losses
atl_loss=pd.concat([atl_home_loss,atl_away_loss])

# %%
atl_loss.losing_abbr.value_counts()
# Out:
# ATL    5
# Name: losing_abbr, dtype: int64

# %%
#combine to make complete 2016 playoffs
atl_21=pd.concat([atl_wins,atl_loss])

# %%
atl_21.head()
# Out:
#                        time        venue  attendance duration time_of_day  \
# date
# 2021-10-11  1:07 p.m. Local  Truist Park       41479     3:20         Day
# 2021-10-12  5:15 p.m. Local  Truist Park       40195     3:53       Night
# 2021-10-16  8:08 p.m. Local  Truist Park       41815     3:04       Night
# 2021-10-17  7:38 p.m. Local  Truist Park       41873     3:56       Night
# 2021-10-23  8:08 p.m. Local  Truist Park       43060     3:32       Night
#
#            winner    winning_name winning_abbr          losing_name  \
# date
# 2021-10-11   Home  Atlanta Braves          ATL    Milwaukee Brewers
# 2021-10-12   Home  Atlanta Braves          ATL    Milwaukee Brewers
# 2021-10-16   Home  Atlanta Braves          ATL  Los Angeles Dodgers
# 2021-10-17   Home  Atlanta Braves          ATL  Los Angeles Dodgers
# 2021-10-23   Home  Atlanta Braves          ATL  Los Angeles Dodgers
#
#            losing_abbr  ...  home_strikes_looking  home_grounded_balls  \
# date                    ...
# 2021-10-11         MIL  ...                    20                    6
# 2021-10-12         MIL  ...                    19                   12
# 2021-10-16         LAD  ...                    18                    7
# 2021-10-17         LAD  ...                    18                   10
# 2021-10-23         LAD  ...                    22                    4
#
#             home_fly_balls  home_line_drives  home_unknown_bat_type  \
# date
# 2021-10-11              17                 5                      0
# 2021-10-12              15                 4                      0
# 2021-10-16              10                 4                      0
# 2021-10-17              13                 6                      0
# 2021-10-23              15                 6                      0
#
#             home_game_score  home_inherited_runners  home_inherited_score  \
# date
# 2021-10-11               67                       0                     0
# 2021-10-12               48                       2                     1
# 2021-10-16               53                       0                     0
# 2021-10-17               44                       3                     2
# 2021-10-23               55                       2                     0
#
#             home_win_probability_by_pitcher  home_base_out_runs_saved
# date
# 2021-10-11                            0.477                       4.9
# 2021-10-12                            0.234                       0.9
# 2021-10-16                            0.493                       2.9
# 2021-10-17                            0.045                       0.9
# 2021-10-23                            0.364                       2.9
#
# [5 rows x 80 columns]

# %% [markdown]
# ### Team Reg Season Function walkthrough outside to find potential bugs

# %%
df_21=df.rename(columns={'home_home_runs':'home_HR','away_home_runs':'away_HR'})

# %%
df_21.columns
# Out:
# Index(['time', 'venue', 'attendance', 'duration', 'time_of_day', 'winner',
#        'winning_name', 'winning_abbr', 'losing_name', 'losing_abbr',
#        'away_at_bats', 'away_runs', 'away_hits', 'away_rbi',
#        'away_earned_runs', 'away_bases_on_balls', 'away_strikeouts',
#        'away_plate_appearances', 'away_batting_average',
#        'away_on_base_percentage', 'away_slugging_percentage',
#        'away_on_base_plus', 'away_pitches', 'away_strikes',
#        'away_win_probability_for_offensive_player',
#        'away_average_leverage_index', 'away_win_probability_added',
#        'away_win_probability_subtracted', 'away_base_out_runs_added',
#        'away_putouts', 'away_assists', 'away_innings_pitched', 'away_HR',
#        'away_strikes_by_contact', 'away_strikes_swinging',
#        'away_strikes_looking', 'away_grounded_balls', 'away_fly_balls',
#        'away_line_drives', 'away_unknown_bat_type', 'away_game_score',
#        'away_inherited_runners', 'away_inherited_score',
#        'away_win_probability_by_pitcher', 'away_base_out_runs_saved',
#        'home_at_bats', 'home_runs', 'home_hits', 'home_rbi',
#        'home_earned_runs', 'home_bases_on_balls', 'home_strikeouts',
#        'home_plate_appearances', 'home_batting_average',
#        'home_on_base_percentage', 'home_slugging_percentage',
#        'home_on_base_plus', 'home_pitches', 'home_strikes',
#        'home_win_probability_for_offensive_player',
#        'home_average_leverage_index', 'home_win_probability_added',
#        'home_win_probability_subtracted', 'home_base_out_runs_added',
#        'home_putouts', 'home_assists', 'home_innings_pitched', 'home_HR',
#        'home_strikes_by_contact', 'home_strikes_swinging',
#        'home_strikes_looking', 'home_grounded_balls', 'home_fly_balls',
#        'home_line_drives', 'home_unknown_bat_type', 'home_game_score',
#        'home_inherited_runners', 'home_inherited_score',
#        'home_win_probability_by_pitcher', 'home_base_out_runs_saved'],
#       dtype='object')

# %%
#Isolate Home winners and away winners into their own df
Home = df_21[(df_21['winner'] == 'Home')] 
Away= df_21[(df_21['winner'] == 'Away')]

# %%
#NYY home wins and losses isolated then combined to only have their stats from those games
home_wins=Home[(Home['winning_abbr'] == 'NYY')]
home_loss=Away[(Away['losing_abbr'] == 'NYY')]
home_games= pd.concat([home_wins,home_loss])
home_offense = home_games.filter(like = 'home')

# %%
#NYY away wins and losses isolated then combined to only have their stats from those games
away_wins=Away[(Away['winning_abbr']=='NYY')]
away_loss=Home[(Home['losing_abbr']=='NYY')]
away_games= pd.concat([away_wins,away_loss])
away_offense = away_games.filter(like = 'away')

# %%
#Get rid of the words home/away
home_offense.columns = home_offense.columns.str.replace('home_','')
away_offense.columns = away_offense.columns.str.replace('away_','')

# %%
#home_offense.drop('away_runs',axis=1,inplace=True)

# %%
#Check to make sure that the columns are the same for both data frames
home_offense.columns==away_offense.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
#Combine dataframes to make one dataframe of all this teams stats
team_offense = pd.concat([home_offense, away_offense])

# %%
#From the teams given home games take the stats of the team they played against
home_games_opponents = home_games.filter(like = 'away')
away_games_opponents = away_games.filter(like = 'home')

# %%
#Get rid of the words home/away
home_games_opponents.columns = home_games_opponents.columns.str.replace('away_','')
away_games_opponents.columns = away_games_opponents.columns.str.replace('home_','')

# %%
#Combine to make dataframe of stats from all opponents 
team_opponents= pd.concat([home_games_opponents,away_games_opponents])

# %%
#Combine theirs and the opponents to make one full data frame for the team, put an Opp_ 
#prefix in front of opponent stats
team_full_check = pd.concat([team_offense, team_opponents.add_prefix('Opp_')], axis = 1)

# %%
team_full_check.head()
# Out:
#             at_bats  runs  hits  rbi  earned_runs  bases_on_balls  strikeouts  \
# date
# 2021-10-05       32     2     6    2          2.0               0          11
#
#             plate_appearances  batting_average  on_base_percentage  ...  \
# date                                                                ...
# 2021-10-05                 32            0.188               0.188  ...
#
#             Opp_strikes_looking  Opp_grounded_balls  Opp_fly_balls  \
# date
# 2021-10-05                   23                   8             11
#
#             Opp_line_drives  Opp_unknown_bat_type  Opp_game_score  \
# date
# 2021-10-05                4                     0              64
#
#             Opp_inherited_runners Opp_inherited_score  \
# date
# 2021-10-05                      1                   0
#
#             Opp_win_probability_by_pitcher  Opp_base_out_runs_saved
# date
# 2021-10-05                           0.323                      3.1
#
# [1 rows x 70 columns]

# %% [markdown]
# I need to create a column that has the teams name in it all the way down, below I will try and make this column using the LAD as my example

# %%
#create name column and fill it with the new LAD variable made above
team_full_check =team_full_check.assign(name='NYY')

# %%
team_full_check = team_full_check.groupby('name').mean().reset_index()

# %%
team_full_check
# Out:
#   name  at_bats  runs  hits  rbi  earned_runs  bases_on_balls  strikeouts  \
# 0  NYY       32     2     6    2          2.0               0          11
#
#    plate_appearances  batting_average  ...  Opp_strikes_looking  \
# 0                 32            0.188  ...                   23
#
#    Opp_grounded_balls  Opp_fly_balls  Opp_line_drives  Opp_unknown_bat_type  \
# 0                   8             11                4                     0
#
#    Opp_game_score  Opp_inherited_runners  Opp_inherited_score  \
# 0              64                      1                    0
#
#    Opp_win_probability_by_pitcher  Opp_base_out_runs_saved
# 0                           0.323                      3.1
#
# [1 rows x 69 columns]

# %% [markdown]
# ### Build reusable Function

# %%
def team_regular_season(df,team,average=True,num=162):
    #Set year range for what games you want to access
    #Rename columns to avoid deletetion later
    df=df.rename(columns={'home_home_runs':'home_HR','away_home_runs':'away_HR'})
    
        #Get all the home winner and away winner games alone
    Home = df[(df['winner'] == 'Home')] 
    Away= df[(df['winner'] == 'Away')]
    
        #Get games where the team was the home team
    home_wins=Home[(Home['winning_abbr'] == team)]
    home_loss=Away[(Away['losing_abbr'] == team)]
    home_games= pd.concat([home_wins,home_loss])
    home_offense = home_games.filter(like = 'home')
    
      #Get games where the team was the away team
    away_wins=Away[(Away['winning_abbr']==team)]
    away_loss=Home[(Home['losing_abbr']==team)]
    away_games= pd.concat([away_wins,away_loss])
    away_offense = away_games.filter(like = 'away')
    
        # split the dataframes to only have the statistics of the given team
    home_offense.columns = home_offense.columns.str.replace('home_','')
    away_offense.columns = away_offense.columns.str.replace('away_','')
    
    #combine offensive stats into one df
    team_offense = pd.concat([home_offense, away_offense])
    
        # create oppposing team statistics from the given games
    home_games_opponents = home_games.filter(like = 'away')
    away_games_opponents = away_games.filter(like = 'home')
    
        # rename the columns from the opponent statistics dataframes
    home_games_opponents.columns = home_games_opponents.columns.str.replace('away_','')
    away_games_opponents.columns = away_games_opponents.columns.str.replace('home_','')
    
    team_opponents= pd.concat([home_games_opponents,away_games_opponents])
    
        # concat the team stats and the opponent stats to create a full picture of the team's season
    team_full = pd.concat([team_offense, team_opponents.add_prefix('Opp_')], axis = 1)
    team_full = team_full.assign(name=team)
    
    # Certain teams only played 161 games this season and therefor need different number
#     club_161=['DET','CLE','MIA','ATL']
#     if team in club_161:
#         num=161
#     else:
#         num=162
#     add= ((team,)*num)
#     team_full['name']= add

    
    
        # return either the season averages or the game by game statistics
    if average:
            team_full = team_full.groupby('name').mean().reset_index()
    
    
    return team_full

# %%
#Check unique names
df.losing_abbr.unique()
# Out:
# array(['NYY', 'STL', 'CHW', 'BOS', 'ATL', 'TBR', 'LAD', 'MIL', 'SFG',
#        'HOU'], dtype=object)

# %%
#Below examined that each teams abbr was working in the function including the 161 teams
dodgers_21=team_regular_season(df,'LAD')

# %%
dodgers_21
# Out:
#   name    at_bats  runs      hits  rbi  earned_runs  bases_on_balls  \
# 0  LAD  33.416667   4.0  8.166667  4.0     4.166667        3.166667
#
#    strikeouts  plate_appearances  batting_average  ...  Opp_strikes_looking  \
# 0    8.333333              37.25           0.2375  ...                23.25
#
#    Opp_grounded_balls  Opp_fly_balls  Opp_line_drives  Opp_unknown_bat_type  \
# 0                8.25      14.333333         5.833333                   0.0
#
#    Opp_game_score  Opp_inherited_runners  Opp_inherited_score  \
# 0       53.666667               2.416667             0.916667
#
#    Opp_win_probability_by_pitcher  Opp_base_out_runs_saved
# 0                        0.097583                 0.516667
#
# [1 rows x 69 columns]

# %% [markdown]
# ### Single Game Function Walkthrough to find/fix bugs

# %%
#create regular seasons using yankees and dodgers as our example
nyy_21=team_regular_season(df,'NYY')
lad_21=team_regular_season(df,'LAD')

# %%
#Concat them as if they are playing against one another 
pd.concat([nyy_21, lad_21])
# Out:
#   name    at_bats  runs      hits  rbi  earned_runs  bases_on_balls  \
# 0  NYY  32.000000   2.0  6.000000  2.0     2.000000        0.000000
# 0  LAD  33.416667   4.0  8.166667  4.0     4.166667        3.166667
#
#    strikeouts  plate_appearances  batting_average  ...  Opp_strikes_looking  \
# 0   11.000000              32.00           0.1880  ...                23.00
# 0    8.333333              37.25           0.2375  ...                23.25
#
#    Opp_grounded_balls  Opp_fly_balls  Opp_line_drives  Opp_unknown_bat_type  \
# 0                8.00      11.000000         4.000000                   0.0
# 0                8.25      14.333333         5.833333                   0.0
#
#    Opp_game_score  Opp_inherited_runners  Opp_inherited_score  \
# 0       64.000000               1.000000             0.000000
# 0       53.666667               2.416667             0.916667
#
#    Opp_win_probability_by_pitcher  Opp_base_out_runs_saved
# 0                        0.323000                 3.100000
# 0                        0.097583                 0.516667
#
# [2 rows x 69 columns]

# %%
#Try this as we may prefer it to all be in one row
pd.concat([nyy_21.add_prefix('H_'), lad_21.add_prefix('A_')], axis = 1)
# Out:
#   H_name  H_at_bats  H_runs  H_hits  H_rbi  H_earned_runs  H_bases_on_balls  \
# 0    NYY         32       2       6      2            2.0                 0
#
#    H_strikeouts  H_plate_appearances  H_batting_average  ...  \
# 0            11                   32              0.188  ...
#
#    A_Opp_strikes_looking  A_Opp_grounded_balls  A_Opp_fly_balls  \
# 0                  23.25                  8.25        14.333333
#
#    A_Opp_line_drives  A_Opp_unknown_bat_type  A_Opp_game_score  \
# 0           5.833333                     0.0         53.666667
#
#    A_Opp_inherited_runners  A_Opp_inherited_score  \
# 0                 2.416667               0.916667
#
#    A_Opp_win_probability_by_pitcher  A_Opp_base_out_runs_saved
# 0                          0.097583                   0.516667
#
# [1 rows x 138 columns]

# %% [markdown]
# ### Build Reusable Function

# %%
def single_game(team1_name, team2_name,df=df):
    
    # from the Team abbreviations get a dataframe with the average seasonlong team statistics.
    team1 = team_regular_season(df,team1_name)
    team2 = team_regular_season(df,team2_name)
    
    #make the single game by concating those dataframes
    game = pd.concat([team1.add_prefix('H_'), team2.add_prefix('A_')], axis = 1)
    
    return game

# %% [markdown]
# ###  Create Season Function Walkthrough to Find Bugs

# %%
#df_16.drop(['index'],axis=1,inplace=True)

# %%
df_21.head()
# Out:
#                        time             venue  attendance duration  \
# date
# 2021-10-05  8:08 p.m. Local       Fenway Park       38324     3:13
# 2021-10-06  5:10 p.m. Local    Dodger Stadium       53193     4:15
# 2021-10-07  3:07 p.m. Local  Minute Maid Park       40497     3:34
# 2021-10-07  8:07 p.m. Local   Tropicana Field       27419     3:06
# 2021-10-08  1:07 p.m. Local  Minute Maid Park       41315     3:52
#
#            time_of_day winner         winning_name winning_abbr  \
# date
# 2021-10-05       Night   Home       Boston Red Sox          BOS
# 2021-10-06       Night   Home  Los Angeles Dodgers          LAD
# 2021-10-07         Day   Home       Houston Astros          HOU
# 2021-10-07       Night   Home       Tampa Bay Rays          TBR
# 2021-10-08         Day   Home       Houston Astros          HOU
#
#                     losing_name losing_abbr  ...  home_strikes_looking  \
# date                                         ...
# 2021-10-05     New York Yankees         NYY  ...                    23
# 2021-10-06  St. Louis Cardinals         STL  ...                    26
# 2021-10-07    Chicago White Sox         CHW  ...                    21
# 2021-10-07       Boston Red Sox         BOS  ...                    17
# 2021-10-08    Chicago White Sox         CHW  ...                    23
#
#             home_grounded_balls  home_fly_balls  home_line_drives  \
# date
# 2021-10-05                    8              11                 4
# 2021-10-06                   10              15                 9
# 2021-10-07                   13              13                 7
# 2021-10-07                    9              15                 5
# 2021-10-08                    9              16                 7
#
#             home_unknown_bat_type  home_game_score  home_inherited_runners  \
# date
# 2021-10-05                      0               64                       1
# 2021-10-06                      0               54                       3
# 2021-10-07                      0               70                       2
# 2021-10-07                      0               60                       0
# 2021-10-08                      0               38                       2
#
#             home_inherited_score  home_win_probability_by_pitcher  \
# date
# 2021-10-05                     0                            0.323
# 2021-10-06                     0                            0.573
# 2021-10-07                     0                            0.266
# 2021-10-07                     0                            0.309
# 2021-10-08                     2                           -0.039
#
#             home_base_out_runs_saved
# date
# 2021-10-05                       3.1
# 2021-10-06                       3.6
# 2021-10-07                       3.7
# 2021-10-07                       4.3
# 2021-10-08                       0.7
#
# [5 rows x 80 columns]

# %%
#Reset the index
df_21.reset_index(inplace=True)

# %% [markdown]
# In the cells below I will try and alter the dataframes so rather than tellin us the winning and losing name it will return the names of the home or away team

# %%
#Get home winners and Away winners in their own dataframe
Home =df_21[(df_21['winner'] == 'Home')] 
Away= df_21[(df_21['winner'] == 'Away')]

# %%
#Rename columns in the home win from winner and loser to home and away
Home=Home.rename(columns={'winning_abbr':'home_abbr','winning_name':'home_name','losing_name':'away_name',
                         'losing_abbr':'away_abbr'})

# %%
#Rename columns in the away win from winner and loser to home and away
Away= Away.rename(columns={'winning_abbr':'away_abbr','winning_name':'away_name','losing_name':'home_name',
                         'losing_abbr':'home_abbr'})

# %%
#Concat these to make season_df now the same but with these new column names
df_21= pd.concat([Home,Away])

# %%
#Get Home and away alone once again
Home = df_21[(df_21['winner'] == 'Home')] 
Away= df_21[(df_21['winner'] == 'Away')]

# %%
#Create a winning abbreviation column
Home['winning_abbr']= Home['home_abbr']
Away['winning_abbr']= Away['away_abbr']
# Out:
# <ipython-input-125-12da05963abd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Home['winning_abbr']= Home['home_abbr']
# <ipython-input-125-12da05963abd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Away['winning_abbr']= Away['away_abbr']

# %%
#Concat to update season_df
df_21=pd.concat([Home,Away])

# %%
#make it sorted in order of date
df_21=df_21.sort_values('date')

# %%
df_21.head()
# Out:
#         date             time             venue  attendance duration  \
# 0 2021-10-05  8:08 p.m. Local       Fenway Park       38324     3:13
# 1 2021-10-06  5:10 p.m. Local    Dodger Stadium       53193     4:15
# 2 2021-10-07  3:07 p.m. Local  Minute Maid Park       40497     3:34
# 3 2021-10-07  8:07 p.m. Local   Tropicana Field       27419     3:06
# 4 2021-10-08  1:07 p.m. Local  Minute Maid Park       41315     3:52
#
#   time_of_day winner            home_name home_abbr            away_name  ...  \
# 0       Night   Home       Boston Red Sox       BOS     New York Yankees  ...
# 1       Night   Home  Los Angeles Dodgers       LAD  St. Louis Cardinals  ...
# 2         Day   Home       Houston Astros       HOU    Chicago White Sox  ...
# 3       Night   Home       Tampa Bay Rays       TBR       Boston Red Sox  ...
# 4         Day   Home       Houston Astros       HOU    Chicago White Sox  ...
#
#   home_grounded_balls  home_fly_balls  home_line_drives  \
# 0                   8              11                 4
# 1                  10              15                 9
# 2                  13              13                 7
# 3                   9              15                 5
# 4                   9              16                 7
#
#    home_unknown_bat_type  home_game_score  home_inherited_runners  \
# 0                      0               64                       1
# 1                      0               54                       3
# 2                      0               70                       2
# 3                      0               60                       0
# 4                      0               38                       2
#
#    home_inherited_score  home_win_probability_by_pitcher  \
# 0                     0                            0.323
# 1                     0                            0.573
# 2                     0                            0.266
# 3                     0                            0.309
# 4                     2                           -0.039
#
#    home_base_out_runs_saved  winning_abbr
# 0                       3.1           BOS
# 1                       3.6           LAD
# 2                       3.7           HOU
# 3                       4.3           TBR
# 4                       0.7           HOU
#
# [5 rows x 82 columns]

# %%
# create a list with the two teams, home team always first, the season, and the day number of the game
matchups = list(zip(df_21.home_abbr, df_21.away_abbr, df_21.date, df_21.winning_abbr))

# %%
#Check matchups
matchups[-2]
# Out:
# ('ATL', 'HOU', Timestamp('2021-10-31 00:00:00'), 'HOU')

# %%
#empty season_games list
season_games = []

# %%
#loop through matchups and create single games for each matchup using that function, then append to season games
for team in matchups:
        game = single_game(team[0], team[1],df)
        season_games.append(game)

# %%
#create df_prep as a example for what will hopefully happen in a function
df_prep = pd.concat(season_games, axis = 0)

# %%
#reset_index
df_prep.reset_index(inplace = True, drop = True)

# %%
df_prep
# Out:
#    H_name  H_at_bats    H_runs     H_hits     H_rbi  H_earned_runs  \
# 0     BOS  35.454545  5.454545   9.545455  5.363636       5.340000
# 1     LAD  33.416667  4.000000   8.166667  4.000000       4.166667
# 2     HOU  34.125000  5.437500   8.875000  5.250000       5.124375
# 3     TBR  36.750000  5.000000   7.750000  4.750000       4.847500
# 4     HOU  34.125000  5.437500   8.875000  5.250000       5.124375
# 5     MIL  31.250000  1.500000   6.000000  1.500000       1.562500
# 6     SFG  31.800000  2.000000   5.800000  2.000000       2.100000
# 7     TBR  36.750000  5.000000   7.750000  4.750000       4.847500
# 8     MIL  31.250000  1.500000   6.000000  1.500000       1.562500
# 9     SFG  31.800000  2.000000   5.800000  2.000000       2.100000
# 10    BOS  35.454545  5.454545   9.545455  5.363636       5.340000
# 11    CHW  35.250000  4.500000  10.250000  4.500000       4.875000
# 12    LAD  33.416667  4.000000   8.166667  4.000000       4.166667
# 13    BOS  35.454545  5.454545   9.545455  5.363636       5.340000
# 14    ATL  33.312500  4.062500   8.187500  4.000000       4.097500
# 15    ATL  33.312500  4.062500   8.187500  4.000000       4.097500
# 16    CHW  35.250000  4.500000  10.250000  4.500000       4.875000
# 17    LAD  33.416667  4.000000   8.166667  4.000000       4.166667
# 18    SFG  31.800000  2.000000   5.800000  2.000000       2.100000
# 19    HOU  34.125000  5.437500   8.875000  5.250000       5.124375
# 20    ATL  33.312500  4.062500   8.187500  4.000000       4.097500
# 21    HOU  34.125000  5.437500   8.875000  5.250000       5.124375
# 22    ATL  33.312500  4.062500   8.187500  4.000000       4.097500
# 23    BOS  35.454545  5.454545   9.545455  5.363636       5.340000
# 24    LAD  33.416667  4.000000   8.166667  4.000000       4.166667
# 25    BOS  35.454545  5.454545   9.545455  5.363636       5.340000
# 26    LAD  33.416667  4.000000   8.166667  4.000000       4.166667
# 27    BOS  35.454545  5.454545   9.545455  5.363636       5.340000
# 28    LAD  33.416667  4.000000   8.166667  4.000000       4.166667
# 29    HOU  34.125000  5.437500   8.875000  5.250000       5.124375
# 30    ATL  33.312500  4.062500   8.187500  4.000000       4.097500
# 31    HOU  34.125000  5.437500   8.875000  5.250000       5.124375
# 32    HOU  34.125000  5.437500   8.875000  5.250000       5.124375
# 33    ATL  33.312500  4.062500   8.187500  4.000000       4.097500
# 34    ATL  33.312500  4.062500   8.187500  4.000000       4.097500
# 35    ATL  33.312500  4.062500   8.187500  4.000000       4.097500
# 36    HOU  34.125000  5.437500   8.875000  5.250000       5.124375
#
#     H_bases_on_balls  H_strikeouts  H_plate_appearances  H_batting_average  \
# 
_Opp_win_probability_by_pitcher  A_Opp_base_out_runs_saved
# 0                           0.323000                   3.100000
# 1                           0.573000                   3.600000
# 2                          -0.070000                   0.075000
# 3                          -0.008818                  -0.563636
# 4                          -0.070000                   0.075000
# 5                          -0.040750                   0.518750
# 6                           0.097583                   0.516667
# 7                          -0.008818                  -0.563636
# 8                          -0.040750                   0.518750
# 9                           0.097583                   0.516667
# 10                          0.111000                   0.150000
# 11                         -0.052500                  -0.781250
# 12                          0.274400                   2.440000
# 13                          0.111000                   0.150000
# 14                          0.331750                   3.150000
# 15                          0.331750                   3.150000
# 16                         -0.052500                  -0.781250
# 17                          0.274400                   2.440000
# 18                          0.097583                   0.516667
# 19                         -0.008818                  -0.563636
# 20                          0.097583                   0.516667
# 21                         -0.008818                  -0.563636
# 22                          0.097583                   0.516667
# 23                         -0.052500                  -0.781250
# 24                         -0.040750                   0.518750
# 25                         -0.052500                  -0.781250
# 26                         -0.040750                   0.518750
# 27                         -0.052500                  -0.781250
# 28                         -0.040750                   0.518750
# 29                         -0.008818                  -0.563636
# 30                          0.097583                   0.516667
# 31                         -0.040750                   0.518750
# 32                         -0.040750                   0.518750
# 33                         -0.052500                  -0.781250
# 34                         -0.052500                  -0.781250
# 35                         -0.052500                  -0.781250
# 36                         -0.040750                   0.518750
#
# [37 rows x 138 columns]

# %%
#Create new column where it will have a 1 if home team won and 0 if away team won
df_prep['home_win'] = np.where(df_21.home_abbr ==df_21.winning_abbr,
                  [1],
                  [0])

# %%
#Examine our new column
df_prep.home_win.value_counts(normalize=True)
# Out:
# 1    0.648649
# 0    0.351351
# Name: home_win, dtype: float64

# %%
df_prep.tail()
# Out:
#    H_name  H_at_bats  H_runs  H_hits  H_rbi  H_earned_runs  H_bases_on_balls  \
# 32    HOU    34.1250  5.4375  8.8750   5.25       5.124375            3.4375
# 33    ATL    33.3125  4.0625  8.1875   4.00       4.097500            3.0625
# 34    ATL    33.3125  4.0625  8.1875   4.00       4.097500            3.0625
# 35    ATL    33.3125  4.0625  8.1875   4.00       4.097500            3.0625
# 36    HOU    34.1250  5.4375  8.8750   5.25       5.124375            3.4375
#
#     H_strikeouts  H_plate_appearances  H_batting_average  ...  \
# 32        8.6875              38.4375           0.255875  ...
# 33       10.1250              36.7500           0.242875  ...
# 34       10.1250              36.7500           0.242875  ...
# 35       10.1250              36.7500           0.242875  ...
# 36        8.6875              38.4375           0.255875  ...
#
#     A_Opp_grounded_balls  A_Opp_fly_balls  A_Opp_line_drives  \
# 32               10.0625           13.375             5.5625
# 33               11.3125           13.000             5.1875
# 34               11.3125           13.000             5.1875
# 35               11.3125           13.000             5.1875
# 36               10.0625           13.375             5.5625
#
#     A_Opp_unknown_bat_type  A_Opp_game_score  A_Opp_inherited_runners  \
# 32                     0.0           46.0000                   1.8750
# 33                     0.0           48.8125                   2.5625
# 34                     0.0           48.8125                   2.5625
# 35                     0.0           48.8125                   2.5625
# 36                     0.0           46.0000                   1.8750
#
#     A_Opp_inherited_score  A_Opp_win_probability_by_pitcher  \
# 32                  0.375                          -0.04075
# 33                  1.125                          -0.05250
# 34                  1.125                          -0.05250
# 35                  1.125                          -0.05250
# 36                  0.375                          -0.04075
#
#     A_Opp_base_out_runs_saved  home_win
# 32                    0.51875         1
# 33                   -0.78125         1
# 34                   -0.78125         1
# 35                   -0.78125         0
# 36                    0.51875         0
#
# [5 rows x 139 columns]

# %%
playoffs_21=df_prep

# %% [markdown]
# ***

# %% [markdown]
# ### Create Season Dataframe

# %%
playoffs_21.head(10)
# Out:
#   H_name  H_at_bats    H_runs    H_hits     H_rbi  H_earned_runs  \
# 0    BOS  35.454545  5.454545  9.545455  5.363636       5.340000
# 1    LAD  33.416667  4.000000  8.166667  4.000000       4.166667
# 2    HOU  34.125000  5.437500  8.875000  5.250000       5.124375
# 3    TBR  36.750000  5.000000  7.750000  4.750000       4.847500
# 4    HOU  34.125000  5.437500  8.875000  5.250000       5.124375
# 5    MIL  31.250000  1.500000  6.000000  1.500000       1.562500
# 6    SFG  31.800000  2.000000  5.800000  2.000000       2.100000
# 7    TBR  36.750000  5.000000  7.750000  4.750000       4.847500
# 8    MIL  31.250000  1.500000  6.000000  1.500000       1.562500
# 9    SFG  31.800000  2.000000  5.800000  2.000000       2.100000
#
#    H_bases_on_balls  H_strikeouts  H_plate_appearances  H_batting_average  \
# 0          3.363636      8.090909            39.363636           0.256091
# 1          3.166667      8.333333            37.250000           0.237500
# 2          3.437500      8.687500            38.437500           0.255875
# 3          2.750000     11.500000            39.500000           0.211500
# 4          3.437500      8.687500            38.437500           0.255875
# 5          2.250000     12.000000            34.500000           0.190750
# 6          1.200000      9.800000            33.200000           0.181800
# 7          2.750000     11.500000            39.500000           0.211500
# 8          2.250000     12.000000            34.500000           0.190750
# 9          1.200000      9.800000            33.200000           0.181800
#
#    ...  A_Opp_grounded_balls  A_Opp_fly_balls  A_Opp_line_drives  \
# 0  ...              8.000000        11.000000           4.000000
# 1  ...             10.000000        15.000000           9.000000
# 2  ...             11.750000        13.500000           6.250000
# 3  ...              9.727273        16.363636           6.363636
# 4  ...             11.750000        13.500000           6.250000
# 5  ...             10.062500        13.375000           5.562500
# 6  ...              8.250000        14.333333           5.833333
# 7  ...              9.727273        16.363636           6.363636
# 8  ...             10.062500        13.375000           5.562500
# 9  ...              8.250000        14.333333           5.833333
#
#    A_Opp_unknown_bat_type  A_Opp_game_score  A_Opp_inherited_runners  \
# 0                     0.0         64.000000                 1.000000
# 1                     0.0         54.000000                 3.000000
# 2                     0.0         46.500000                 2.500000
# 3                     0.0         44.818182                 2.272727
# 4                     0.0         46.500000                 2.500000
# 5                     0.0         46.000000                 1.875000
# 6                     0.0         53.666667                 2.416667
# 7                     0.0         44.818182                 2.272727
# 8                     0.0         46.000000                 1.875000
# 9                     0.0         53.666667                 2.416667
#
#    A_Opp_inherited_score  A_Opp_win_probability_by_pitcher  \
# 0               0.000000                          0.323000
# 1               0.000000                          0.573000
# 2               1.500000                         -0.070000
# 3               0.545455                         -0.008818
# 4               1.500000                         -0.070000
# 5               0.375000                         -0.040750
# 6               0.916667                          0.097583
# 7               0.545455                         -0.008818
# 8               0.375000                         -0.040750
# 9               0.916667                          0.097583
#
#    A_Opp_base_out_runs_saved  home_win
# 0                   3.100000         1
# 1                   3.600000         1
# 2                   0.075000         1
# 3                  -0.563636         1
# 4                   0.075000         1
# 5                   0.518750         1
# 6                   0.516667         1
# 7                  -0.563636         0
# 8                   0.518750         0
# 9                   0.516667         0
#
# [10 rows x 139 columns]

# %%
playoffs_21.drop_duplicates(inplace=True)

# %%
playoffs_21.reset_index(inplace=True)

# %%
playoffs_21.drop('index',axis=1,inplace=True)

# %%
playoffs_21.to_csv('../data/Playoffs_2021.csv')
